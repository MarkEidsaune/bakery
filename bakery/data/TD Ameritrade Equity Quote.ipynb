# %% [markdown]
# # TD Ameritrade API
# ## Equity Quote

# %% [markdown]
# Install modules

# %%
import sys
# !{sys.executable} -m pip install

# %% [markdown]
# Load modules

# %%
from auth import TDClient
from us_holidays_cal import USHolidaysCalendar

# %%
import os
import requests
import json
import pandas as pd
import numpy as np
from datetime import datetime, date, timedelta
from cassandra.cluster import Cluster

# %% [markdown]
# Set project directory and paths to credentials and tokens files

# %%
base_path = os.path.join(os.path.expanduser('~'), 'bakery')
creds_path = os.path.join(base_path, 'td_ameritrade/creds.json')
token_path = os.path.join(base_path, 'td_ameritrade/tokens.json')

# %% [markdown]
# Connect to Cassandra cluster

# %%
session = Cluster().connect()

# %% [markdown]
# Check if today is a weekend or holiday

# %%
current_year = date.today().year
cal = USHolidaysCalendar()
holidays = cal.holidays(
    start=date(current_year, 1, 1), 
    end=date(current_year, 12, 31)
)
holidays = [holiday.date() for holiday in holidays]

# %%
today = date.today()

is_weekend = today.weekday() in [5, 6]
if is_weekend:
    print('Today is not a weekday')
is_holiday = today in holidays
if is_holiday:
    print('Today is a holiday')
# Out:
# Today is a holiday

# %% [markdown]
# Get list of symbols from Cassandra table: bakery.symbols

# %%
def list_factory(colnames, rows):
    return [row[0] for row in rows]
session.row_factory = list_factory

query = "select symbol from bakery.symbols;"
symbols = session.execute(query, timeout=None)
symbols = [symbol for symbol in symbols]

# %% [markdown]
# Get authentication object

# %%
td_client = TDClient()
td_client.refresh_tokens()
td_auth = td_client.get_auth()
# Out:
# Access token expired. Calling get_token_from_refresh_token()
# Access token has been successfully updated

# %% [markdown]
# ##### Get quotes for list of symbols

# %%
def chunker(ls, size):
    return (ls[pos:pos + size] for pos in range(0, len(ls), size))

# %%
for chunk in chunker(symbols, 100):
    
    symbols_str = ','.join(chunk)
    
    params = {
            'symbol': symbols_str
        }

    request_ts = int(datetime.now().timestamp()) * 1000
    
    r = requests.get(
            'https://api.tdameritrade.com/v1/marketdata/quotes',
            auth=td_auth,
            params=params
        )
    
    for s in r.json():
        values = (
            s, 
            request_ts,
            r.json()[s]['assetType'],
            r.json()[s]['assetMainType'],
            r.json()[s]['cusip'],
            r.json()[s]['assetSubType'],
            r.json()[s]['description'].replace("'", ""),
            r.json()[s]['bidPrice'],
            r.json()[s]['bidSize'],
            r.json()[s]['bidId'],
            r.json()[s]['askPrice'],
            r.json()[s]['askSize'],
            r.json()[s]['askId'],
            r.json()[s]['lastPrice'],
            r.json()[s]['lastSize'],
            r.json()[s]['lastId'],
            r.json()[s]['openPrice'],
            r.json()[s]['highPrice'],
            r.json()[s]['lowPrice'],
            r.json()[s]['bidTick'],
            r.json()[s]['closePrice'],
            r.json()[s]['netChange'],
            r.json()[s]['totalVolume'],
            r.json()[s]['quoteTimeInLong'],
            r.json()[s]['tradeTimeInLong'],
            r.json()[s]['mark'],
            r.json()[s]['exchange'],
            r.json()[s]['exchangeName'],
            r.json()[s]['marginable'],
            r.json()[s]['shortable'],
            r.json()[s]['volatility'],
            r.json()[s]['digits'],
            r.json()[s]['52WkHigh'],
            r.json()[s]['52WkLow'],
            r.json()[s]['nAV'],
            r.json()[s]['peRatio'],
            r.json()[s]['divAmount'],
            r.json()[s]['divYield'],
            r.json()[s]['divDate'],
            r.json()[s]['securityStatus'],
            r.json()[s]['regularMarketLastPrice'],
            r.json()[s]['regularMarketLastSize'],
            r.json()[s]['regularMarketNetChange'],
            r.json()[s]['regularMarketTradeTimeInLong'],
            r.json()[s]['netPercentChangeInDouble'],
            r.json()[s]['markChangeInDouble'],
            r.json()[s]['markPercentChangeInDouble'],
            r.json()[s]['regularMarketPercentChangeInDouble'],
            r.json()[s]['delayed'],
            r.json()[s]['realtimeEntitled'],        
        )

        session.execute(
            f'''
            INSERT INTO bakery.quotes_daily 
                (symbol, request_ts, asset_type, asset_main_type, cusip, asset_subtype, description, 
                bid_price, bid_size, bid_id, ask_price, ask_size, ask_id, last_price, last_size, 
                last_id, open_price, high_price, low_price, bid_tick, close_price, net_change, 
                total_volume, quote_time_in_long, trade_time_in_long, mark, exchange, exchange_name, 
                marginable, shortable, volatility, digits, high_52_wk, low_52_wk, nav, pe_ratio, 
                div_amount, div_yield, div_date, security_status, regular_market_last_price, 
                regular_market_last_size, regular_market_net_change, regular_market_trade_time_in_long, 
                net_percent_change_in_double, mark_change_in_double, mark_percent_change_in_double, 
                regular_market_percent_change_in_double, delayed, real_time_entitled)
            VALUES {values}
            '''
        )

# %%
r.json()
# Out:
# {'FCPT': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '35086T109',
#   'assetSubType': '',
#   'symbol': 'FCPT',
#   'description': 'Four Corners Property Trust, Inc. Common Stock',
#   'bidPrice': 28.46,
#   'bidSize': 400,
#   'bidId': 'T',
#   'askPrice': 28.48,
#   'askSize': 100,
#   'askId': 'K',
#   'lastPrice': 28.46,
#   'lastSize': 100,
#   'lastId': 'U',
#   'openPrice': 28.44,
#   'highPrice': 28.48,
#   'lowPrice': 28.1,
#   'bidTick': ' ',
#   'closePrice': 28.45,
#   'netChange': 0.01,
#   'totalVolume': 119096,
#   'quoteTimeInLong': 1659728587913,
#   'tradeTimeInLong': 1659728551008,
#   'mark': 28.46,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0478,
#   'digits': 2,
#   '52WkHigh': 30.13,
#   '52WkLow': 24.24,
#   'nAV': 0.0,
#   'peRatio': 23.3896,
#   'divAmount': 1.33,
#   'divYield': 4.67,
#   'divDate': '2022-06-29 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 28.46,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.01,
#   'regularMarketTradeTimeInLong': 1659728551008,
#   'netPercentChangeInDouble': 0.0351,
#   'markChangeInDouble': 0.01,
#   'markPercentChangeInDouble': 0.0351,
#   'regularMarketPercentChangeInDouble': 0.0351,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'NATR': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '639027101',
#   'assetSubType': '',
#   'symbol': 'NATR',
#   'description': "Nature's Sunshine Products, Inc. - Common Stock",
#   'bidPrice': 10.71,
#   'bidSize': 300,
#   'bidId': 'B',
#   'askPrice': 10.75,
#   'askSize': 200,
#   'askId': 'Q',
#   'lastPrice': 10.73,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 10.82,
#   'highPrice': 10.86,
#   'lowPrice': 10.56,
#   'bidTick': ' ',
#   'closePrice': 10.82,
#   'netChange': -0.09,
#   'totalVolume': 14744,
#   'quoteTimeInLong': 1659728209522,
#   'tradeTimeInLong': 1659728523952,
#   'mark': 10.73,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.2152,
#   'digits': 4,
#   '52WkHigh': 19.2575,
#   '52WkLow': 10.17,
#   'nAV': 0.0,
#   'peRatio': 9.64,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 10.73,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.09,
#   'regularMarketTradeTimeInLong': 1659728523952,
#   'netPercentChangeInDouble': -0.8318,
#   'markChangeInDouble': -0.09,
#   'markPercentChangeInDouble': -0.8318,
#   'regularMarketPercentChangeInDouble': -0.8318,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'FLO': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '343498101',
#   'assetSubType': '',
#   'symbol': 'FLO',
#   'description': 'Flowers Foods, Inc. Common Stock',
#   'bidPrice': 27.73,
#   'bidSize': 500,
#   'bidId': 'U',
#   'askPrice': 27.74,
#   'askSize': 500,
#   'askId': 'T',
#   'lastPrice': 27.735,
#   'lastSize': 100,
#   'lastId': 'T',
#   'openPrice': 27.55,
#   'highPrice': 27.74,
#   'lowPrice': 27.17,
#   'bidTick': ' ',
#   'closePrice': 27.63,
#   'netChange': 0.105,
#   'totalVolume': 798459,
#   'quoteTimeInLong': 1659728590373,
#   'tradeTimeInLong': 1659728588565,
#   'mark': 27.735,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.1072,
#   'digits': 2,
#   '52WkHigh': 29.73,
#   '52WkLow': 22.61,
#   'nAV': 0.0,
#   'peRatio': 27.0721,
#   'divAmount': 0.88,
#   'divYield': 3.18,
#   'divDate': '2022-06-08 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 27.735,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.105,
#   'regularMarketTradeTimeInLong': 1659728588565,
#   'netPercentChangeInDouble': 0.38,
#   'markChangeInDouble': 0.105,
#   'markPercentChangeInDouble': 0.38,
#   'regularMarketPercentChangeInDouble': 0.38,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'TNC': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '880345103',
#   'assetSubType': '',
#   'symbol': 'TNC',
#   'description': 'Tennant Company Common Stock',
#   'bidPrice': 65.32,
#   'bidSize': 200,
#   'bidId': 'N',
#   'askPrice': 65.53,
#   'askSize': 200,
#   'askId': 'N',
#   'lastPrice': 65.42,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 64.38,
#   'highPrice': 65.53,
#   'lowPrice': 64.14,
#   'bidTick': ' ',
#   'closePrice': 65.21,
#   'netChange': 0.21,
#   'totalVolume': 14167,
#   'quoteTimeInLong': 1659728288988,
#   'tradeTimeInLong': 1659728468183,
#   'mark': 65.42,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.2232,
#   'digits': 2,
#   '52WkHigh': 85.33,
#   '52WkLow': 54.9023,
#   'nAV': 0.0,
#   'peRatio': 25.033,
#   'divAmount': 1.0,
#   'divYield': 1.53,
#   'divDate': '2022-05-27 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 65.42,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.21,
#   'regularMarketTradeTimeInLong': 1659728468183,
#   'netPercentChangeInDouble': 0.322,
#   'markChangeInDouble': 0.21,
#   'markPercentChangeInDouble': 0.322,
#   'regularMarketPercentChangeInDouble': 0.322,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'GRPH': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '38870X104',
#   'assetSubType': '',
#   'symbol': 'GRPH',
#   'description': 'Graphite Bio, Inc. - Common Stock',
#   'bidPrice': 3.56,
#   'bidSize': 500,
#   'bidId': 'K',
#   'askPrice': 3.57,
#   'askSize': 300,
#   'askId': 'Q',
#   'lastPrice': 3.565,
#   'lastSize': 100,
#   'lastId': 'Q',
#   'openPrice': 3.44,
#   'highPrice': 3.565,
#   'lowPrice': 3.37,
#   'bidTick': ' ',
#   'closePrice': 3.48,
#   'netChange': 0.085,
#   'totalVolume': 232787,
#   'quoteTimeInLong': 1659728582480,
#   'tradeTimeInLong': 1659728550922,
#   'mark': 3.565,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.1478,
#   'digits': 4,
#   '52WkHigh': 23.3699,
#   '52WkLow': 2.07,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 3.565,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.085,
#   'regularMarketTradeTimeInLong': 1659728550922,
#   'netPercentChangeInDouble': 2.4425,
#   'markChangeInDouble': 0.085,
#   'markPercentChangeInDouble': 2.4425,
#   'regularMarketPercentChangeInDouble': 2.4425,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'PKE': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '70014A104',
#   'assetSubType': '',
#   'symbol': 'PKE',
#   'description': 'Park Aerospace Corp. Common Stock',
#   'bidPrice': 12.47,
#   'bidSize': 100,
#   'bidId': 'N',
#   'askPrice': 12.56,
#   'askSize': 200,
#   'askId': 'T',
#   'lastPrice': 12.53,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 12.18,
#   'highPrice': 12.65,
#   'lowPrice': 12.015,
#   'bidTick': ' ',
#   'closePrice': 12.06,
#   'netChange': 0.47,
#   'totalVolume': 61372,
#   'quoteTimeInLong': 1659728583880,
#   'tradeTimeInLong': 1659728278765,
#   'mark': 12.53,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.1955,
#   'digits': 2,
#   '52WkHigh': 15.55,
#   '52WkLow': 11.27,
#   'nAV': 0.0,
#   'peRatio': 32.8622,
#   'divAmount': 0.4,
#   'divYield': 3.32,
#   'divDate': '2022-06-30 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 12.53,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.47,
#   'regularMarketTradeTimeInLong': 1659728278765,
#   'netPercentChangeInDouble': 3.8972,
#   'markChangeInDouble': 0.47,
#   'markPercentChangeInDouble': 3.8972,
#   'regularMarketPercentChangeInDouble': 3.8972,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'ALX': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '014752109',
#   'assetSubType': '',
#   'symbol': 'ALX',
#   'description': "Alexander's, Inc. Common Stock",
#   'bidPrice': 248.66,
#   'bidSize': 100,
#   'bidId': 'T',
#   'askPrice': 250.0,
#   'askSize': 100,
#   'askId': 'Z',
#   'lastPrice': 248.1,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 252.47,
#   'highPrice': 254.145,
#   'lowPrice': 247.54,
#   'bidTick': ' ',
#   'closePrice': 256.49,
#   'netChange': -8.39,
#   'totalVolume': 3989,
#   'quoteTimeInLong': 1659728569470,
#   'tradeTimeInLong': 1659726745340,
#   'mark': 248.66,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.6082,
#   'digits': 2,
#   '52WkHigh': 299.99,
#   '52WkLow': 213.85,
#   'nAV': 0.0,
#   'peRatio': 11.2929,
#   'divAmount': 18.0,
#   'divYield': 7.02,
#   'divDate': '2022-08-05 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 248.1,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -8.39,
#   'regularMarketTradeTimeInLong': 1659726745340,
#   'netPercentChangeInDouble': -3.2711,
#   'markChangeInDouble': -7.83,
#   'markPercentChangeInDouble': -3.0527,
#   'regularMarketPercentChangeInDouble': -3.2711,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'OMC': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '681919106',
#   'assetSubType': '',
#   'symbol': 'OMC',
#   'description': 'Omnicom Group Inc. Common Stock',
#   'bidPrice': 68.99,
#   'bidSize': 100,
#   'bidId': 'U',
#   'askPrice': 69.0,
#   'askSize': 400,
#   'askId': 'N',
#   'lastPrice': 68.995,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 69.42,
#   'highPrice': 69.73,
#   'lowPrice': 68.89,
#   'bidTick': ' ',
#   'closePrice': 70.3,
#   'netChange': -1.305,
#   'totalVolume': 557803,
#   'quoteTimeInLong': 1659728580768,
#   'tradeTimeInLong': 1659728576009,
#   'mark': 68.995,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0293,
#   'digits': 2,
#   '52WkHigh': 91.61,
#   '52WkLow': 61.31,
#   'nAV': 0.0,
#   'peRatio': 11.7929,
#   'divAmount': 2.8,
#   'divYield': 3.98,
#   'divDate': '2022-09-20 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 68.995,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -1.305,
#   'regularMarketTradeTimeInLong': 1659728576009,
#   'netPercentChangeInDouble': -1.8563,
#   'markChangeInDouble': -1.305,
#   'markPercentChangeInDouble': -1.8563,
#   'regularMarketPercentChangeInDouble': -1.8563,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'OLIT': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '68218C108',
#   'assetSubType': '',
#   'symbol': 'OLIT',
#   'description': 'OmniLit Acquisition Corp. - Class A Common Stock',
#   'bidPrice': 10.03,
#   'bidSize': 6700,
#   'bidId': 'Q',
#   'askPrice': 10.05,
#   'askSize': 1000,
#   'askId': 'Q',
#   'lastPrice': 10.04,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 0.0,
#   'highPrice': 0.0,
#   'lowPrice': 0.0,
#   'bidTick': ' ',
#   'closePrice': 10.04,
#   'netChange': 0.0,
#   'totalVolume': 0,
#   'quoteTimeInLong': 1659710519057,
#   'tradeTimeInLong': 1659626359143,
#   'mark': 10.04,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': False,
#   'shortable': False,
#   'volatility': 0.0,
#   'digits': 4,
#   '52WkHigh': 10.04,
#   '52WkLow': 9.84,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 10.04,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.0,
#   'regularMarketTradeTimeInLong': 1659626359143,
#   'netPercentChangeInDouble': 0.0,
#   'markChangeInDouble': 0.0,
#   'markPercentChangeInDouble': 0.0,
#   'regularMarketPercentChangeInDouble': 0.0,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'FATP': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': 'G3400W102',
#   'assetSubType': '',
#   'symbol': 'FATP',
#   'description': 'Fat Projects Acquisition Corp - Class A Ordinary Share',
#   'bidPrice': 9.95,
#   'bidSize': 100,
#   'bidId': 'Q',
#   'askPrice': 9.97,
#   'askSize': 6000,
#   'askId': 'Q',
#   'lastPrice': 9.95,
#   'lastSize': 900,
#   'lastId': 'Q',
#   'openPrice': 9.95,
#   'highPrice': 9.95,
#   'lowPrice': 9.94,
#   'bidTick': ' ',
#   'closePrice': 9.94,
#   'netChange': 0.01,
#   'totalVolume': 13630,
#   'quoteTimeInLong': 1659719278161,
#   'tradeTimeInLong': 1659719278161,
#   'mark': 9.95,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': False,
#   'shortable': False,
#   'volatility': 0.0396,
#   'digits': 4,
#   '52WkHigh': 9.9699,
#   '52WkLow': 9.695,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 9.95,
#   'regularMarketLastSize': 9,
#   'regularMarketNetChange': 0.01,
#   'regularMarketTradeTimeInLong': 1659719278161,
#   'netPercentChangeInDouble': 0.1006,
#   'markChangeInDouble': 0.01,
#   'markPercentChangeInDouble': 0.1006,
#   'regularMarketPercentChangeInDouble': 0.1006,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'FSP': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '35471R106',
#   'assetSubType': '',
#   'symbol': 'FSP',
#   'description': 'Franklin Street Properties Corp. Common Stock',
#   'bidPrice': 3.34,
#   'bidSize': 800,
#   'bidId': 'T',
#   'askPrice': 3.35,
#   'askSize': 1200,
#   'askId': 'T',
#   'lastPrice': 3.345,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 3.37,
#   'highPrice': 3.38,
#   'lowPrice': 3.295,
#   'bidTick': ' ',
#   'closePrice': 3.42,
#   'netChange': -0.075,
#   'totalVolume': 603925,
#   'quoteTimeInLong': 1659728580135,
#   'tradeTimeInLong': 1659728567738,
#   'mark': 3.345,
#   'exchange': 'a',
#   'exchangeName': 'AMEX',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0845,
#   'digits': 4,
#   '52WkHigh': 6.58,
#   '52WkLow': 3.295,
#   'nAV': 0.0,
#   'peRatio': 5.3854,
#   'divAmount': 0.04,
#   'divYield': 1.17,
#   'divDate': '2022-07-18 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 3.345,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.075,
#   'regularMarketTradeTimeInLong': 1659728567738,
#   'netPercentChangeInDouble': -2.193,
#   'markChangeInDouble': -0.075,
#   'markPercentChangeInDouble': -2.193,
#   'regularMarketPercentChangeInDouble': -2.193,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'MBTC': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': 'G6580S114',
#   'assetSubType': '',
#   'symbol': 'MBTC',
#   'description': 'Nocturne Acquisition Corporation - Ordinary Shares',
#   'bidPrice': 10.26,
#   'bidSize': 5000,
#   'bidId': 'Q',
#   'askPrice': 10.27,
#   'askSize': 30800,
#   'askId': 'Q',
#   'lastPrice': 10.27,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 10.26,
#   'highPrice': 10.27,
#   'lowPrice': 10.26,
#   'bidTick': ' ',
#   'closePrice': 10.26,
#   'netChange': 0.01,
#   'totalVolume': 42204,
#   'quoteTimeInLong': 1659728414086,
#   'tradeTimeInLong': 1659712152281,
#   'mark': 10.27,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': False,
#   'shortable': False,
#   'volatility': 0.0588,
#   'digits': 4,
#   '52WkHigh': 10.27,
#   '52WkLow': 9.8692,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 10.27,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.01,
#   'regularMarketTradeTimeInLong': 1659712152281,
#   'netPercentChangeInDouble': 0.0975,
#   'markChangeInDouble': 0.01,
#   'markPercentChangeInDouble': 0.0975,
#   'regularMarketPercentChangeInDouble': 0.0975,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'BYN': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '06690B107',
#   'assetSubType': '',
#   'symbol': 'BYN',
#   'description': 'Banyan Acquisition Corporation Class A Common Stock',
#   'bidPrice': 9.98,
#   'bidSize': 1800,
#   'bidId': 'P',
#   'askPrice': 10.0,
#   'askSize': 1800,
#   'askId': 'T',
#   'lastPrice': 9.98,
#   'lastSize': 100,
#   'lastId': 'N',
#   'openPrice': 0.0,
#   'highPrice': 0.0,
#   'lowPrice': 0.0,
#   'bidTick': ' ',
#   'closePrice': 9.98,
#   'netChange': 0.0,
#   'totalVolume': 0,
#   'quoteTimeInLong': 1659706211161,
#   'tradeTimeInLong': 1659654000001,
#   'mark': 9.98,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': False,
#   'shortable': False,
#   'volatility': 0.0,
#   'digits': 2,
#   '52WkHigh': 10.01,
#   '52WkLow': 9.86,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 9.98,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.0,
#   'regularMarketTradeTimeInLong': 1659654000001,
#   'netPercentChangeInDouble': 0.0,
#   'markChangeInDouble': 0.0,
#   'markPercentChangeInDouble': 0.0,
#   'regularMarketPercentChangeInDouble': 0.0,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'MNTX': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '563420108',
#   'assetSubType': '',
#   'symbol': 'MNTX',
#   'description': 'Manitex International, Inc. - common stock',
#   'bidPrice': 5.72,
#   'bidSize': 100,
#   'bidId': 'Q',
#   'askPrice': 5.88,
#   'askSize': 200,
#   'askId': 'Y',
#   'lastPrice': 5.7703,
#   'lastSize': 200,
#   'lastId': 'D',
#   'openPrice': 5.786,
#   'highPrice': 5.786,
#   'lowPrice': 5.7703,
#   'bidTick': ' ',
#   'closePrice': 5.76,
#   'netChange': 0.0103,
#   'totalVolume': 640,
#   'quoteTimeInLong': 1659728113202,
#   'tradeTimeInLong': 1659724850311,
#   'mark': 5.7703,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0,
#   'digits': 4,
#   '52WkHigh': 8.54,
#   '52WkLow': 5.58,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 5.7703,
#   'regularMarketLastSize': 2,
#   'regularMarketNetChange': 0.0103,
#   'regularMarketTradeTimeInLong': 1659724850311,
#   'netPercentChangeInDouble': 0.1788,
#   'markChangeInDouble': 0.0103,
#   'markPercentChangeInDouble': 0.1788,
#   'regularMarketPercentChangeInDouble': 0.1788,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'PCYO': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '746228303',
#   'assetSubType': '',
#   'symbol': 'PCYO',
#   'description': 'Pure Cycle Corporation - Common Stock',
#   'bidPrice': 10.63,
#   'bidSize': 300,
#   'bidId': 'Q',
#   'askPrice': 10.69,
#   'askSize': 100,
#   'askId': 'Q',
#   'lastPrice': 10.66,
#   'lastSize': 100,
#   'lastId': 'Q',
#   'openPrice': 10.6467,
#   'highPrice': 10.745,
#   'lowPrice': 10.62,
#   'bidTick': ' ',
#   'closePrice': 10.8,
#   'netChange': -0.14,
#   'totalVolume': 11293,
#   'quoteTimeInLong': 1659728488312,
#   'tradeTimeInLong': 1659728331667,
#   'mark': 10.66,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0,
#   'digits': 4,
#   '52WkHigh': 16.55,
#   '52WkLow': 9.46,
#   'nAV': 0.0,
#   'peRatio': 44.71,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 10.66,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.14,
#   'regularMarketTradeTimeInLong': 1659728331667,
#   'netPercentChangeInDouble': -1.2963,
#   'markChangeInDouble': -0.14,
#   'markPercentChangeInDouble': -1.2963,
#   'regularMarketPercentChangeInDouble': -1.2963,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'T': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '00206R102',
#   'assetSubType': '',
#   'symbol': 'T',
#   'description': 'AT&T Inc.',
#   'bidPrice': 18.28,
#   'bidSize': 15600,
#   'bidId': 'N',
#   'askPrice': 18.29,
#   'askSize': 26900,
#   'askId': 'K',
#   'lastPrice': 18.285,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 18.27,
#   'highPrice': 18.31,
#   'lowPrice': 18.09,
#   'bidTick': ' ',
#   'closePrice': 18.27,
#   'netChange': 0.015,
#   'totalVolume': 25506295,
#   'quoteTimeInLong': 1659728590373,
#   'tradeTimeInLong': 1659728589221,
#   'mark': 18.285,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0173,
#   'digits': 2,
#   '52WkHigh': 21.53,
#   '52WkLow': 16.629,
#   'nAV': 0.0,
#   'peRatio': 6.8001,
#   'divAmount': 1.11,
#   'divYield': 6.08,
#   'divDate': '2022-07-08 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 18.285,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.015,
#   'regularMarketTradeTimeInLong': 1659728589221,
#   'netPercentChangeInDouble': 0.0821,
#   'markChangeInDouble': 0.015,
#   'markPercentChangeInDouble': 0.0821,
#   'regularMarketPercentChangeInDouble': 0.0821,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'TIOA': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': 'G8T10C106',
#   'assetSubType': '',
#   'symbol': 'TIOA',
#   'description': 'Tio Tech A - Class A Ordinary Share',
#   'bidPrice': 9.8,
#   'bidSize': 10400,
#   'bidId': 'Q',
#   'askPrice': 9.83,
#   'askSize': 30400,
#   'askId': 'Q',
#   'lastPrice': 9.8,
#   'lastSize': 5200,
#   'lastId': 'D',
#   'openPrice': 0.0,
#   'highPrice': 0.0,
#   'lowPrice': 0.0,
#   'bidTick': ' ',
#   'closePrice': 9.8,
#   'netChange': 0.0,
#   'totalVolume': 0,
#   'quoteTimeInLong': 1659722510475,
#   'tradeTimeInLong': 1659545657745,
#   'mark': 9.8,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': False,
#   'shortable': False,
#   'volatility': 0.0,
#   'digits': 4,
#   '52WkHigh': 9.97,
#   '52WkLow': 9.59,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 9.8,
#   'regularMarketLastSize': 52,
#   'regularMarketNetChange': 0.0,
#   'regularMarketTradeTimeInLong': 1659545657745,
#   'netPercentChangeInDouble': 0.0,
#   'markChangeInDouble': 0.0,
#   'markPercentChangeInDouble': 0.0,
#   'regularMarketPercentChangeInDouble': 0.0,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'DCRD': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': 'G2773W103',
#   'assetSubType': '',
#   'symbol': 'DCRD',
#   'description': 'Decarbonization Plus Acquisition Corporation IV - Class A Ordinary Share',
#   'bidPrice': 9.96,
#   'bidSize': 27300,
#   'bidId': 'Q',
#   'askPrice': 9.98,
#   'askSize': 30100,
#   'askId': 'Q',
#   'lastPrice': 9.96,
#   'lastSize': 100,
#   'lastId': 'Q',
#   'openPrice': 0.0,
#   'highPrice': 0.0,
#   'lowPrice': 0.0,
#   'bidTick': ' ',
#   'closePrice': 9.96,
#   'netChange': 0.0,
#   'totalVolume': 2,
#   'quoteTimeInLong': 1659709782469,
#   'tradeTimeInLong': 1659639601084,
#   'mark': 9.96,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': False,
#   'shortable': False,
#   'volatility': 0.0,
#   'digits': 4,
#   '52WkHigh': 10.56,
#   '52WkLow': 9.75,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 9.96,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.0,
#   'regularMarketTradeTimeInLong': 1659639601084,
#   'netPercentChangeInDouble': 0.0,
#   'markChangeInDouble': 0.0,
#   'markPercentChangeInDouble': 0.0,
#   'regularMarketPercentChangeInDouble': 0.0,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'RC': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '75574U101',
#   'assetSubType': '',
#   'symbol': 'RC',
#   'description': 'Ready Capital Corproation Common Stock',
#   'bidPrice': 13.66,
#   'bidSize': 700,
#   'bidId': 'N',
#   'askPrice': 13.67,
#   'askSize': 1000,
#   'askId': 'N',
#   'lastPrice': 13.67,
#   'lastSize': 100,
#   'lastId': 'V',
#   'openPrice': 13.7,
#   'highPrice': 13.935,
#   'lowPrice': 13.57,
#   'bidTick': ' ',
#   'closePrice': 13.58,
#   'netChange': 0.09,
#   'totalVolume': 607761,
#   'quoteTimeInLong': 1659728580600,
#   'tradeTimeInLong': 1659728588374,
#   'mark': 13.67,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0596,
#   'digits': 2,
#   '52WkHigh': 16.5585,
#   '52WkLow': 11.05,
#   'nAV': 0.0,
#   'peRatio': 6.2026,
#   'divAmount': 1.68,
#   'divYield': 12.37,
#   'divDate': '2022-06-29 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 13.67,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.09,
#   'regularMarketTradeTimeInLong': 1659728588374,
#   'netPercentChangeInDouble': 0.6627,
#   'markChangeInDouble': 0.09,
#   'markPercentChangeInDouble': 0.6627,
#   'regularMarketPercentChangeInDouble': 0.6627,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'CDNA': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '14167L103',
#   'assetSubType': '',
#   'symbol': 'CDNA',
#   'description': 'CareDx, Inc. - Common Stock',
#   'bidPrice': 26.11,
#   'bidSize': 100,
#   'bidId': 'Q',
#   'askPrice': 26.14,
#   'askSize': 100,
#   'askId': 'Q',
#   'lastPrice': 26.11,
#   'lastSize': 100,
#   'lastId': 'Q',
#   'openPrice': 23.69,
#   'highPrice': 26.195,
#   'lowPrice': 21.76,
#   'bidTick': ' ',
#   'closePrice': 24.3,
#   'netChange': 1.81,
#   'totalVolume': 1098729,
#   'quoteTimeInLong': 1659728590248,
#   'tradeTimeInLong': 1659728588243,
#   'mark': 26.11,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.1189,
#   'digits': 4,
#   '52WkHigh': 84.94,
#   '52WkLow': 19.345,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 26.11,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 1.81,
#   'regularMarketTradeTimeInLong': 1659728588243,
#   'netPercentChangeInDouble': 7.4486,
#   'markChangeInDouble': 1.81,
#   'markPercentChangeInDouble': 7.4486,
#   'regularMarketPercentChangeInDouble': 7.4486,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'VET': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '923725105',
#   'assetSubType': '',
#   'symbol': 'VET',
#   'description': 'Vermilion Energy Inc. Common (Canada)',
#   'bidPrice': 22.98,
#   'bidSize': 100,
#   'bidId': 'U',
#   'askPrice': 22.98,
#   'askSize': 100,
#   'askId': 'N',
#   'lastPrice': 22.985,
#   'lastSize': 100,
#   'lastId': 'T',
#   'openPrice': 21.56,
#   'highPrice': 23.3244,
#   'lowPrice': 21.41,
#   'bidTick': ' ',
#   'closePrice': 22.05,
#   'netChange': 0.935,
#   'totalVolume': 1903215,
#   'quoteTimeInLong': 1659728588271,
#   'tradeTimeInLong': 1659728588270,
#   'mark': 22.98,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0452,
#   'digits': 2,
#   '52WkHigh': 26.02,
#   '52WkLow': 5.51,
#   'nAV': 0.0,
#   'peRatio': 5.29,
#   'divAmount': 0.1402,
#   'divYield': 0.64,
#   'divDate': '2022-06-29 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 22.985,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.935,
#   'regularMarketTradeTimeInLong': 1659728588270,
#   'netPercentChangeInDouble': 4.2404,
#   'markChangeInDouble': 0.93,
#   'markPercentChangeInDouble': 4.2177,
#   'regularMarketPercentChangeInDouble': 4.2404,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'XPO': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '983793100',
#   'assetSubType': '',
#   'symbol': 'XPO',
#   'description': 'XPO Logistics, Inc.',
#   'bidPrice': 60.05,
#   'bidSize': 100,
#   'bidId': 'P',
#   'askPrice': 60.08,
#   'askSize': 300,
#   'askId': 'N',
#   'lastPrice': 60.065,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 59.68,
#   'highPrice': 60.38,
#   'lowPrice': 58.25,
#   'bidTick': ' ',
#   'closePrice': 61.25,
#   'netChange': -1.185,
#   'totalVolume': 1676633,
#   'quoteTimeInLong': 1659728587464,
#   'tradeTimeInLong': 1659728588160,
#   'mark': 60.065,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.2393,
#   'digits': 2,
#   '52WkHigh': 90.78,
#   '52WkLow': 45.09,
#   'nAV': 0.0,
#   'peRatio': 9.83,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 60.065,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -1.185,
#   'regularMarketTradeTimeInLong': 1659728588160,
#   'netPercentChangeInDouble': -1.9347,
#   'markChangeInDouble': -1.185,
#   'markPercentChangeInDouble': -1.9347,
#   'regularMarketPercentChangeInDouble': -1.9347,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'CLR': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '212015101',
#   'assetSubType': '',
#   'symbol': 'CLR',
#   'description': 'Continental Resources, Inc. Common Stock',
#   'bidPrice': 66.74,
#   'bidSize': 100,
#   'bidId': 'N',
#   'askPrice': 66.79,
#   'askSize': 100,
#   'askId': 'N',
#   'lastPrice': 66.74,
#   'lastSize': 100,
#   'lastId': 'N',
#   'openPrice': 64.68,
#   'highPrice': 68.04,
#   'lowPrice': 64.07,
#   'bidTick': ' ',
#   'closePrice': 65.09,
#   'netChange': 1.65,
#   'totalVolume': 712868,
#   'quoteTimeInLong': 1659728585139,
#   'tradeTimeInLong': 1659728584205,
#   'mark': 66.74,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0591,
#   'digits': 2,
#   '52WkHigh': 75.49,
#   '52WkLow': 32.15,
#   'nAV': 0.0,
#   'peRatio': 8.3161,
#   'divAmount': 1.12,
#   'divYield': 1.72,
#   'divDate': '2022-08-05 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 66.74,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 1.65,
#   'regularMarketTradeTimeInLong': 1659728584205,
#   'netPercentChangeInDouble': 2.535,
#   'markChangeInDouble': 1.65,
#   'markPercentChangeInDouble': 2.535,
#   'regularMarketPercentChangeInDouble': 2.535,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'GFI': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '38059T106',
#   'assetSubType': 'ADR',
#   'symbol': 'GFI',
#   'description': 'Gold Fields Limited American Depositary Shares',
#   'bidPrice': 9.23,
#   'bidSize': 14000,
#   'bidId': 'T',
#   'askPrice': 9.24,
#   'askSize': 9300,
#   'askId': 'T',
#   'lastPrice': 9.235,
#   'lastSize': 100,
#   'lastId': 'T',
#   'openPrice': 9.0,
#   'highPrice': 9.25,
#   'lowPrice': 8.95,
#   'bidTick': ' ',
#   'closePrice': 9.24,
#   'netChange': -0.005,
#   'totalVolume': 3317621,
#   'quoteTimeInLong': 1659728587719,
#   'tradeTimeInLong': 1659728586862,
#   'mark': 9.235,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0364,
#   'digits': 2,
#   '52WkHigh': 17.2,
#   '52WkLow': 7.75,
#   'nAV': 0.0,
#   'peRatio': 9.99,
#   'divAmount': 0.34,
#   'divYield': 3.87,
#   'divDate': '2022-03-10 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 9.235,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.005,
#   'regularMarketTradeTimeInLong': 1659728586862,
#   'netPercentChangeInDouble': -0.0541,
#   'markChangeInDouble': -0.005,
#   'markPercentChangeInDouble': -0.0541,
#   'regularMarketPercentChangeInDouble': -0.0541,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'NCNO': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '63947X101',
#   'assetSubType': '',
#   'symbol': 'NCNO',
#   'description': 'nCino, Inc. - Common Stock',
#   'bidPrice': 35.47,
#   'bidSize': 300,
#   'bidId': 'Q',
#   'askPrice': 35.5,
#   'askSize': 300,
#   'askId': 'Q',
#   'lastPrice': 35.49,
#   'lastSize': 100,
#   'lastId': 'Q',
#   'openPrice': 34.9,
#   'highPrice': 35.98,
#   'lowPrice': 34.21,
#   'bidTick': ' ',
#   'closePrice': 35.65,
#   'netChange': -0.16,
#   'totalVolume': 158321,
#   'quoteTimeInLong': 1659728587239,
#   'tradeTimeInLong': 1659728553613,
#   'mark': 35.49,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.1303,
#   'digits': 4,
#   '52WkHigh': 79.4299,
#   '52WkLow': 23.94,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 35.49,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.16,
#   'regularMarketTradeTimeInLong': 1659728553613,
#   'netPercentChangeInDouble': -0.4488,
#   'markChangeInDouble': -0.16,
#   'markPercentChangeInDouble': -0.4488,
#   'regularMarketPercentChangeInDouble': -0.4488,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'AIKI': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '008875304',
#   'assetSubType': '',
#   'symbol': 'AIKI',
#   'description': 'AIkido Pharma Inc. - Common Stock',
#   'bidPrice': 5.88,
#   'bidSize': 100,
#   'bidId': 'V',
#   'askPrice': 5.94,
#   'askSize': 300,
#   'askId': 'Q',
#   'lastPrice': 5.9,
#   'lastSize': 100,
#   'lastId': 'Q',
#   'openPrice': 5.77,
#   'highPrice': 5.97,
#   'lowPrice': 5.77,
#   'bidTick': ' ',
#   'closePrice': 5.85,
#   'netChange': 0.05,
#   'totalVolume': 13951,
#   'quoteTimeInLong': 1659728560817,
#   'tradeTimeInLong': 1659728465812,
#   'mark': 5.9,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': False,
#   'shortable': False,
#   'volatility': 0.3537,
#   'digits': 4,
#   '52WkHigh': 16.575,
#   '52WkLow': 4.3,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 5.9,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.05,
#   'regularMarketTradeTimeInLong': 1659728465812,
#   'netPercentChangeInDouble': 0.8547,
#   'markChangeInDouble': 0.05,
#   'markPercentChangeInDouble': 0.8547,
#   'regularMarketPercentChangeInDouble': 0.8547,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'RES': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '749660106',
#   'assetSubType': '',
#   'symbol': 'RES',
#   'description': 'RPC, Inc. Common Stock',
#   'bidPrice': 7.27,
#   'bidSize': 1300,
#   'bidId': 'N',
#   'askPrice': 7.28,
#   'askSize': 1100,
#   'askId': 'N',
#   'lastPrice': 7.275,
#   'lastSize': 100,
#   'lastId': 'N',
#   'openPrice': 6.69,
#   'highPrice': 7.51,
#   'lowPrice': 6.69,
#   'bidTick': ' ',
#   'closePrice': 6.8,
#   'netChange': 0.475,
#   'totalVolume': 981250,
#   'quoteTimeInLong': 1659728588011,
#   'tradeTimeInLong': 1659728583728,
#   'mark': 7.275,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0605,
#   'digits': 2,
#   '52WkHigh': 12.91,
#   '52WkLow': 3.33,
#   'nAV': 0.0,
#   'peRatio': 19.9563,
#   'divAmount': 0.02,
#   'divYield': 0.29,
#   'divDate': '2022-08-09 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 7.275,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.475,
#   'regularMarketTradeTimeInLong': 1659728583728,
#   'netPercentChangeInDouble': 6.9853,
#   'markChangeInDouble': 0.475,
#   'markPercentChangeInDouble': 6.9853,
#   'regularMarketPercentChangeInDouble': 6.9853,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'BIDU': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '056752108',
#   'assetSubType': 'ADR',
#   'symbol': 'BIDU',
#   'description': 'Baidu, Inc. - American Depositary Shares, each representing 8 ordinary share',
#   'bidPrice': 137.39,
#   'bidSize': 700,
#   'bidId': 'Q',
#   'askPrice': 137.4,
#   'askSize': 400,
#   'askId': 'Q',
#   'lastPrice': 137.395,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 136.29,
#   'highPrice': 138.435,
#   'lowPrice': 135.51,
#   'bidTick': ' ',
#   'closePrice': 140.07,
#   'netChange': -2.675,
#   'totalVolume': 799768,
#   'quoteTimeInLong': 1659728589602,
#   'tradeTimeInLong': 1659728589605,
#   'mark': 137.395,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0674,
#   'digits': 4,
#   '52WkHigh': 182.6,
#   '52WkLow': 101.6166,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 137.395,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -2.675,
#   'regularMarketTradeTimeInLong': 1659728589605,
#   'netPercentChangeInDouble': -1.9098,
#   'markChangeInDouble': -2.675,
#   'markPercentChangeInDouble': -1.9098,
#   'regularMarketPercentChangeInDouble': -1.9098,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'HRI': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '42704L104',
#   'assetSubType': '',
#   'symbol': 'HRI',
#   'description': 'Herc Holdings Inc. Common Stock',
#   'bidPrice': 123.19,
#   'bidSize': 300,
#   'bidId': 'N',
#   'askPrice': 123.4,
#   'askSize': 200,
#   'askId': 'T',
#   'lastPrice': 123.32,
#   'lastSize': 100,
#   'lastId': 'V',
#   'openPrice': 120.5,
#   'highPrice': 124.19,
#   'lowPrice': 120.5,
#   'bidTick': ' ',
#   'closePrice': 120.96,
#   'netChange': 2.36,
#   'totalVolume': 105176,
#   'quoteTimeInLong': 1659728585084,
#   'tradeTimeInLong': 1659728570030,
#   'mark': 123.32,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.1045,
#   'digits': 2,
#   '52WkHigh': 203.14,
#   '52WkLow': 83.43,
#   'nAV': 0.0,
#   'peRatio': 13.23,
#   'divAmount': 1.725,
#   'divYield': 1.43,
#   'divDate': '2022-05-26 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 123.32,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 2.36,
#   'regularMarketTradeTimeInLong': 1659728570030,
#   'netPercentChangeInDouble': 1.9511,
#   'markChangeInDouble': 2.36,
#   'markPercentChangeInDouble': 1.9511,
#   'regularMarketPercentChangeInDouble': 1.9511,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'CBSH': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '200525103',
#   'assetSubType': '',
#   'symbol': 'CBSH',
#   'description': 'Commerce Bancshares, Inc. - Common Stock',
#   'bidPrice': 71.19,
#   'bidSize': 100,
#   'bidId': 'Q',
#   'askPrice': 71.24,
#   'askSize': 100,
#   'askId': 'Q',
#   'lastPrice': 71.235,
#   'lastSize': 100,
#   'lastId': 'H',
#   'openPrice': 70.61,
#   'highPrice': 71.39,
#   'lowPrice': 70.41,
#   'bidTick': ' ',
#   'closePrice': 70.61,
#   'netChange': 0.625,
#   'totalVolume': 318521,
#   'quoteTimeInLong': 1659728590262,
#   'tradeTimeInLong': 1659728536291,
#   'mark': 71.235,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0395,
#   'digits': 4,
#   '52WkHigh': 74.72,
#   '52WkLow': 61.8095,
#   'nAV': 0.0,
#   'peRatio': 18.19,
#   'divAmount': 1.06,
#   'divYield': 1.5,
#   'divDate': '2022-06-06 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 71.235,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.625,
#   'regularMarketTradeTimeInLong': 1659728536291,
#   'netPercentChangeInDouble': 0.8851,
#   'markChangeInDouble': 0.625,
#   'markPercentChangeInDouble': 0.8851,
#   'regularMarketPercentChangeInDouble': 0.8851,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'PBI': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '724479100',
#   'assetSubType': '',
#   'symbol': 'PBI',
#   'description': 'Pitney Bowes Inc. Common Stock',
#   'bidPrice': 3.23,
#   'bidSize': 6400,
#   'bidId': 'N',
#   'askPrice': 3.24,
#   'askSize': 5400,
#   'askId': 'N',
#   'lastPrice': 3.235,
#   'lastSize': 100,
#   'lastId': 'U',
#   'openPrice': 3.2,
#   'highPrice': 3.29,
#   'lowPrice': 3.18,
#   'bidTick': ' ',
#   'closePrice': 3.23,
#   'netChange': 0.005,
#   'totalVolume': 1394487,
#   'quoteTimeInLong': 1659728574371,
#   'tradeTimeInLong': 1659728578751,
#   'mark': 3.235,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.1025,
#   'digits': 2,
#   '52WkHigh': 8.41,
#   '52WkLow': 3.17,
#   'nAV': 0.0,
#   'peRatio': 16.4239,
#   'divAmount': 0.2,
#   'divYield': 6.19,
#   'divDate': '2022-08-19 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 3.235,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.005,
#   'regularMarketTradeTimeInLong': 1659728578751,
#   'netPercentChangeInDouble': 0.1548,
#   'markChangeInDouble': 0.005,
#   'markPercentChangeInDouble': 0.1548,
#   'regularMarketPercentChangeInDouble': 0.1548,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'PH': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '701094104',
#   'assetSubType': '',
#   'symbol': 'PH',
#   'description': 'Parker-Hannifin Corporation Common Stock',
#   'bidPrice': 292.47,
#   'bidSize': 200,
#   'bidId': 'N',
#   'askPrice': 292.64,
#   'askSize': 100,
#   'askId': 'H',
#   'lastPrice': 292.6,
#   'lastSize': 100,
#   'lastId': 'N',
#   'openPrice': 290.28,
#   'highPrice': 293.84,
#   'lowPrice': 288.93,
#   'bidTick': ' ',
#   'closePrice': 293.47,
#   'netChange': -0.87,
#   'totalVolume': 463081,
#   'quoteTimeInLong': 1659728590149,
#   'tradeTimeInLong': 1659728577559,
#   'mark': 292.6,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0403,
#   'digits': 2,
#   '52WkHigh': 340.0,
#   '52WkLow': 230.44,
#   'nAV': 0.0,
#   'peRatio': 22.4264,
#   'divAmount': 5.32,
#   'divYield': 1.81,
#   'divDate': '2022-05-12 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 292.6,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.87,
#   'regularMarketTradeTimeInLong': 1659728577559,
#   'netPercentChangeInDouble': -0.2965,
#   'markChangeInDouble': -0.87,
#   'markPercentChangeInDouble': -0.2965,
#   'regularMarketPercentChangeInDouble': -0.2965,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'LBPH': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '54300N103',
#   'assetSubType': '',
#   'symbol': 'LBPH',
#   'description': 'Longboard Pharmaceuticals, Inc. - Common Stock',
#   'bidPrice': 3.41,
#   'bidSize': 200,
#   'bidId': 'Q',
#   'askPrice': 3.56,
#   'askSize': 200,
#   'askId': 'Q',
#   'lastPrice': 3.38,
#   'lastSize': 100,
#   'lastId': 'Y',
#   'openPrice': 3.49,
#   'highPrice': 3.49,
#   'lowPrice': 3.37,
#   'bidTick': ' ',
#   'closePrice': 3.54,
#   'netChange': -0.16,
#   'totalVolume': 1245,
#   'quoteTimeInLong': 1659728084063,
#   'tradeTimeInLong': 1659711112212,
#   'mark': 3.41,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': False,
#   'shortable': False,
#   'volatility': 0.0,
#   'digits': 4,
#   '52WkHigh': 11.36,
#   '52WkLow': 2.84,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 3.38,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.16,
#   'regularMarketTradeTimeInLong': 1659711112212,
#   'netPercentChangeInDouble': -4.5198,
#   'markChangeInDouble': -0.13,
#   'markPercentChangeInDouble': -3.6723,
#   'regularMarketPercentChangeInDouble': -4.5198,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'IAG': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '450913108',
#   'assetSubType': '',
#   'symbol': 'IAG',
#   'description': 'Iamgold Corporation Ordinary Shares',
#   'bidPrice': 1.3,
#   'bidSize': 91600,
#   'bidId': 'U',
#   'askPrice': 1.31,
#   'askSize': 84100,
#   'askId': 'T',
#   'lastPrice': 1.3001,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 1.5,
#   'highPrice': 1.5,
#   'lowPrice': 1.29,
#   'bidTick': ' ',
#   'closePrice': 1.49,
#   'netChange': -0.1899,
#   'totalVolume': 10288518,
#   'quoteTimeInLong': 1659728582107,
#   'tradeTimeInLong': 1659728588719,
#   'mark': 1.3001,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0,
#   'digits': 2,
#   '52WkHigh': 3.77,
#   '52WkLow': 1.29,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 1.3001,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.1899,
#   'regularMarketTradeTimeInLong': 1659728588719,
#   'netPercentChangeInDouble': -12.745,
#   'markChangeInDouble': -0.1899,
#   'markPercentChangeInDouble': -12.745,
#   'regularMarketPercentChangeInDouble': -12.745,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'WDI': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '95790K109',
#   'assetSubType': '',
#   'symbol': 'WDI',
#   'description': 'Western Asset Diversified Income Fund Common Shares of Beneficial Interest',
#   'bidPrice': 14.49,
#   'bidSize': 100,
#   'bidId': 'T',
#   'askPrice': 14.52,
#   'askSize': 600,
#   'askId': 'N',
#   'lastPrice': 14.49,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 14.42,
#   'highPrice': 14.61,
#   'lowPrice': 14.42,
#   'bidTick': ' ',
#   'closePrice': 14.4,
#   'netChange': 0.09,
#   'totalVolume': 134566,
#   'quoteTimeInLong': 1659728063534,
#   'tradeTimeInLong': 1659728341771,
#   'mark': 14.49,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': False,
#   'shortable': False,
#   'volatility': 0.1201,
#   'digits': 2,
#   '52WkHigh': 20.4499,
#   '52WkLow': 13.32,
#   'nAV': 0.0,
#   'peRatio': 61.0154,
#   'divAmount': 1.44,
#   'divYield': 10.0,
#   'divDate': '2022-08-23 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 14.49,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.09,
#   'regularMarketTradeTimeInLong': 1659728341771,
#   'netPercentChangeInDouble': 0.625,
#   'markChangeInDouble': 0.09,
#   'markPercentChangeInDouble': 0.625,
#   'regularMarketPercentChangeInDouble': 0.625,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'ANTE': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '00941Q104',
#   'assetSubType': 'ADR',
#   'symbol': 'ANTE',
#   'description': 'AirNet Technology Inc. - American Depositary Shares, each representing ten ordin',
#   'bidPrice': 1.33,
#   'bidSize': 100,
#   'bidId': 'Q',
#   'askPrice': 1.38,
#   'askSize': 1300,
#   'askId': 'Q',
#   'lastPrice': 1.33,
#   'lastSize': 100,
#   'lastId': 'Q',
#   'openPrice': 1.3,
#   'highPrice': 1.39,
#   'lowPrice': 1.3,
#   'bidTick': ' ',
#   'closePrice': 1.33,
#   'netChange': 0.0,
#   'totalVolume': 5612,
#   'quoteTimeInLong': 1659728413290,
#   'tradeTimeInLong': 1659728166253,
#   'mark': 1.33,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.3803,
#   'digits': 4,
#   '52WkHigh': 2.93,
#   '52WkLow': 1.1,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 1.33,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.0,
#   'regularMarketTradeTimeInLong': 1659728166253,
#   'netPercentChangeInDouble': 0.0,
#   'markChangeInDouble': 0.0,
#   'markPercentChangeInDouble': 0.0,
#   'regularMarketPercentChangeInDouble': 0.0,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'CAN': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '134748102',
#   'assetSubType': 'ADR',
#   'symbol': 'CAN',
#   'description': 'Canaan Inc. - American Depositary Shares',
#   'bidPrice': 3.92,
#   'bidSize': 3100,
#   'bidId': 'Q',
#   'askPrice': 3.93,
#   'askSize': 3100,
#   'askId': 'Q',
#   'lastPrice': 3.925,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 3.85,
#   'highPrice': 3.97,
#   'lowPrice': 3.75,
#   'bidTick': ' ',
#   'closePrice': 3.92,
#   'netChange': 0.005,
#   'totalVolume': 965263,
#   'quoteTimeInLong': 1659728580118,
#   'tradeTimeInLong': 1659728572584,
#   'mark': 3.925,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0943,
#   'digits': 4,
#   '52WkHigh': 11.1899,
#   '52WkLow': 2.56,
#   'nAV': 0.0,
#   'peRatio': 1.82,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 3.925,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.005,
#   'regularMarketTradeTimeInLong': 1659728572584,
#   'netPercentChangeInDouble': 0.1276,
#   'markChangeInDouble': 0.005,
#   'markPercentChangeInDouble': 0.1275,
#   'regularMarketPercentChangeInDouble': 0.1276,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'PRGO': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': 'G97822103',
#   'assetSubType': '',
#   'symbol': 'PRGO',
#   'description': 'Perrigo Company plc Ordinary Shares',
#   'bidPrice': 43.01,
#   'bidSize': 100,
#   'bidId': 'U',
#   'askPrice': 43.03,
#   'askSize': 700,
#   'askId': 'N',
#   'lastPrice': 43.035,
#   'lastSize': 100,
#   'lastId': 'N',
#   'openPrice': 42.06,
#   'highPrice': 43.21,
#   'lowPrice': 42.01,
#   'bidTick': ' ',
#   'closePrice': 42.45,
#   'netChange': 0.585,
#   'totalVolume': 779775,
#   'quoteTimeInLong': 1659728588924,
#   'tradeTimeInLong': 1659728557226,
#   'mark': 43.03,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0,
#   'digits': 2,
#   '52WkHigh': 50.8994,
#   '52WkLow': 31.32,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 1.04,
#   'divYield': 2.45,
#   'divDate': '2022-09-01 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 43.035,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.585,
#   'regularMarketTradeTimeInLong': 1659728557226,
#   'netPercentChangeInDouble': 1.3781,
#   'markChangeInDouble': 0.58,
#   'markPercentChangeInDouble': 1.3663,
#   'regularMarketPercentChangeInDouble': 1.3781,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'RFAC': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '74954L104',
#   'assetSubType': '',
#   'symbol': 'RFAC',
#   'description': 'RF Acquisition Corp. - Class A Common Stock',
#   'bidPrice': 9.92,
#   'bidSize': 400,
#   'bidId': 'U',
#   'askPrice': 9.93,
#   'askSize': 5000,
#   'askId': 'K',
#   'lastPrice': 9.92,
#   'lastSize': 100,
#   'lastId': 'K',
#   'openPrice': 9.93,
#   'highPrice': 9.935,
#   'lowPrice': 9.92,
#   'bidTick': ' ',
#   'closePrice': 9.9,
#   'netChange': 0.02,
#   'totalVolume': 238304,
#   'quoteTimeInLong': 1659726765505,
# ...
#   'bidId': 'Q',
#   'askPrice': 3.69,
#   'askSize': 200,
#   'askId': 'Q',
#   'lastPrice': 3.65,
#   'lastSize': 100,
#   'lastId': 'Q',
#   'openPrice': 3.7,
#   'highPrice': 3.76,
#   'lowPrice': 3.65,
#   'bidTick': ' ',
#   'closePrice': 3.72,
#   'netChange': -0.07,
#   'totalVolume': 54903,
#   'quoteTimeInLong': 1659728534571,
#   'tradeTimeInLong': 1659728351146,
#   'mark': 3.65,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0,
#   'digits': 4,
#   '52WkHigh': 13.1,
#   '52WkLow': 2.6,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 3.65,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.07,
#   'regularMarketTradeTimeInLong': 1659728351146,
#   'netPercentChangeInDouble': -1.8817,
#   'markChangeInDouble': -0.07,
#   'markPercentChangeInDouble': -1.8817,
#   'regularMarketPercentChangeInDouble': -1.8817,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'XPOA': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '23344P101',
#   'assetSubType': '',
#   'symbol': 'XPOA',
#   'description': 'DPCM Capital, Inc. Class A Common Stock',
#   'bidPrice': 8.63,
#   'bidSize': 100,
#   'bidId': 'M',
#   'askPrice': 8.68,
#   'askSize': 100,
#   'askId': 'U',
#   'lastPrice': 8.69,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 8.68,
#   'highPrice': 8.83,
#   'lowPrice': 8.56,
#   'bidTick': ' ',
#   'closePrice': 8.68,
#   'netChange': 0.01,
#   'totalVolume': 48406,
#   'quoteTimeInLong': 1659728445224,
#   'tradeTimeInLong': 1659727692736,
#   'mark': 8.68,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.2457,
#   'digits': 2,
#   '52WkHigh': 10.33,
#   '52WkLow': 7.5,
#   'nAV': 0.0,
#   'peRatio': 60.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 8.69,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.01,
#   'regularMarketTradeTimeInLong': 1659727692736,
#   'netPercentChangeInDouble': 0.1152,
#   'markChangeInDouble': 0.0,
#   'markPercentChangeInDouble': 0.0,
#   'regularMarketPercentChangeInDouble': 0.1152,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'BRAG': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '104833306',
#   'assetSubType': '',
#   'symbol': 'BRAG',
#   'description': 'Bragg Gaming Group Inc. - Common Shares',
#   'bidPrice': 6.69,
#   'bidSize': 500,
#   'bidId': 'P',
#   'askPrice': 6.75,
#   'askSize': 400,
#   'askId': 'P',
#   'lastPrice': 6.75,
#   'lastSize': 100,
#   'lastId': 'P',
#   'openPrice': 6.35,
#   'highPrice': 6.75,
#   'lowPrice': 6.35,
#   'bidTick': ' ',
#   'closePrice': 6.42,
#   'netChange': 0.33,
#   'totalVolume': 19576,
#   'quoteTimeInLong': 1659728528197,
#   'tradeTimeInLong': 1659728525276,
#   'mark': 6.75,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0,
#   'digits': 4,
#   '52WkHigh': 12.5,
#   '52WkLow': 2.3,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 6.75,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.33,
#   'regularMarketTradeTimeInLong': 1659728525276,
#   'netPercentChangeInDouble': 5.1402,
#   'markChangeInDouble': 0.33,
#   'markPercentChangeInDouble': 5.1402,
#   'regularMarketPercentChangeInDouble': 5.1402,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'NR': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '651718504',
#   'assetSubType': '',
#   'symbol': 'NR',
#   'description': 'Newpark Resources, Inc. Common Stock',
#   'bidPrice': 2.53,
#   'bidSize': 500,
#   'bidId': 'T',
#   'askPrice': 2.54,
#   'askSize': 1500,
#   'askId': 'N',
#   'lastPrice': 2.53,
#   'lastSize': 100,
#   'lastId': 'U',
#   'openPrice': 2.6,
#   'highPrice': 2.71,
#   'lowPrice': 2.53,
#   'bidTick': ' ',
#   'closePrice': 2.65,
#   'netChange': -0.12,
#   'totalVolume': 944238,
#   'quoteTimeInLong': 1659728550839,
#   'tradeTimeInLong': 1659728580815,
#   'mark': 2.53,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': False,
#   'shortable': False,
#   'volatility': 0.0,
#   'digits': 2,
#   '52WkHigh': 4.8082,
#   '52WkLow': 1.92,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 2.53,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.12,
#   'regularMarketTradeTimeInLong': 1659728580815,
#   'netPercentChangeInDouble': -4.5283,
#   'markChangeInDouble': -0.12,
#   'markPercentChangeInDouble': -4.5283,
#   'regularMarketPercentChangeInDouble': -4.5283,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'DHHC': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '25278L105',
#   'assetSubType': '',
#   'symbol': 'DHHC',
#   'description': 'DiamondHead Holdings Corp. - Class A Common Stock',
#   'bidPrice': 9.86,
#   'bidSize': 2400,
#   'bidId': 'Q',
#   'askPrice': 9.87,
#   'askSize': 3100,
#   'askId': 'K',
#   'lastPrice': 9.865,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 9.87,
#   'highPrice': 9.87,
#   'lowPrice': 9.86,
#   'bidTick': ' ',
#   'closePrice': 9.86,
#   'netChange': 0.005,
#   'totalVolume': 101479,
#   'quoteTimeInLong': 1659728405324,
#   'tradeTimeInLong': 1659727659048,
#   'mark': 9.865,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': False,
#   'shortable': False,
#   'volatility': 0.0565,
#   'digits': 4,
#   '52WkHigh': 9.87,
#   '52WkLow': 9.63,
#   'nAV': 0.0,
#   'peRatio': 33.19,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 9.865,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.005,
#   'regularMarketTradeTimeInLong': 1659727659048,
#   'netPercentChangeInDouble': 0.0507,
#   'markChangeInDouble': 0.005,
#   'markPercentChangeInDouble': 0.0507,
#   'regularMarketPercentChangeInDouble': 0.0507,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'WATT': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '29272C103',
#   'assetSubType': '',
#   'symbol': 'WATT',
#   'description': 'Energous Corporation - Common Stock',
#   'bidPrice': 1.32,
#   'bidSize': 8200,
#   'bidId': 'Q',
#   'askPrice': 1.33,
#   'askSize': 4900,
#   'askId': 'Q',
#   'lastPrice': 1.3245,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 1.29,
#   'highPrice': 1.3399,
#   'lowPrice': 1.26,
#   'bidTick': ' ',
#   'closePrice': 1.29,
#   'netChange': 0.0345,
#   'totalVolume': 223754,
#   'quoteTimeInLong': 1659728420266,
#   'tradeTimeInLong': 1659728574619,
#   'mark': 1.3245,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.2853,
#   'digits': 4,
#   '52WkHigh': 2.78,
#   '52WkLow': 0.8154,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 1.3245,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 0.0345,
#   'regularMarketTradeTimeInLong': 1659728574619,
#   'netPercentChangeInDouble': 2.6744,
#   'markChangeInDouble': 0.0345,
#   'markPercentChangeInDouble': 2.6744,
#   'regularMarketPercentChangeInDouble': 2.6744,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'DTM': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '23345M107',
#   'assetSubType': '',
#   'symbol': 'DTM',
#   'description': 'DT Midstream, Inc. Common Stock',
#   'bidPrice': 54.13,
#   'bidSize': 100,
#   'bidId': 'T',
#   'askPrice': 54.17,
#   'askSize': 300,
#   'askId': 'N',
#   'lastPrice': 54.15,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 52.31,
#   'highPrice': 54.355,
#   'lowPrice': 52.31,
#   'bidTick': ' ',
#   'closePrice': 52.98,
#   'netChange': 1.17,
#   'totalVolume': 361636,
#   'quoteTimeInLong': 1659728589828,
#   'tradeTimeInLong': 1659728586590,
#   'mark': 54.15,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0597,
#   'digits': 2,
#   '52WkHigh': 59.359,
#   '52WkLow': 40.63,
#   'nAV': 0.0,
#   'peRatio': 17.1369,
#   'divAmount': 2.56,
#   'divYield': 4.83,
#   'divDate': '2022-09-16 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 54.15,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': 1.17,
#   'regularMarketTradeTimeInLong': 1659728586590,
#   'netPercentChangeInDouble': 2.2084,
#   'markChangeInDouble': 1.17,
#   'markPercentChangeInDouble': 2.2084,
#   'regularMarketPercentChangeInDouble': 2.2084,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'DOC': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '71943U104',
#   'assetSubType': '',
#   'symbol': 'DOC',
#   'description': 'Physicians Realty Trust Common Shares of Beneficial Interest',
#   'bidPrice': 17.18,
#   'bidSize': 3700,
#   'bidId': 'N',
#   'askPrice': 17.19,
#   'askSize': 1200,
#   'askId': 'T',
#   'lastPrice': 17.185,
#   'lastSize': 100,
#   'lastId': 'V',
#   'openPrice': 17.28,
#   'highPrice': 17.43,
#   'lowPrice': 17.09,
#   'bidTick': ' ',
#   'closePrice': 17.42,
#   'netChange': -0.235,
#   'totalVolume': 861432,
#   'quoteTimeInLong': 1659728590373,
#   'tradeTimeInLong': 1659728590374,
#   'mark': 17.185,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0192,
#   'digits': 2,
#   '52WkHigh': 19.3,
#   '52WkLow': 16.07,
#   'nAV': 0.0,
#   'peRatio': 46.86,
#   'divAmount': 0.92,
#   'divYield': 5.28,
#   'divDate': '2022-07-01 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 17.185,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.235,
#   'regularMarketTradeTimeInLong': 1659728590374,
#   'netPercentChangeInDouble': -1.349,
#   'markChangeInDouble': -0.235,
#   'markPercentChangeInDouble': -1.349,
#   'regularMarketPercentChangeInDouble': -1.349,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'VCV': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '46132H106',
#   'assetSubType': '',
#   'symbol': 'VCV',
#   'description': 'Invesco California Value Municipal Income Trust Common Stock',
#   'bidPrice': 10.61,
#   'bidSize': 600,
#   'bidId': 'N',
#   'askPrice': 10.65,
#   'askSize': 2800,
#   'askId': 'N',
#   'lastPrice': 10.618,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 10.7,
#   'highPrice': 10.74,
#   'lowPrice': 10.56,
#   'bidTick': ' ',
#   'closePrice': 10.76,
#   'netChange': -0.142,
#   'totalVolume': 126018,
#   'quoteTimeInLong': 1659728498724,
#   'tradeTimeInLong': 1659728569554,
#   'mark': 10.618,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0992,
#   'digits': 2,
#   '52WkHigh': 14.49,
#   '52WkLow': 9.68,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.498,
#   'divYield': 4.63,
#   'divDate': '2022-08-12 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 10.618,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.142,
#   'regularMarketTradeTimeInLong': 1659728569554,
#   'netPercentChangeInDouble': -1.3197,
#   'markChangeInDouble': -0.142,
#   'markPercentChangeInDouble': -1.3197,
#   'regularMarketPercentChangeInDouble': -1.3197,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'EAD': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '94987B105',
#   'assetSubType': '',
#   'symbol': 'EAD',
#   'description': 'Allspring Income Opportunities Fund Common Shares',
#   'bidPrice': 7.26,
#   'bidSize': 900,
#   'bidId': 'U',
#   'askPrice': 7.28,
#   'askSize': 2600,
#   'askId': 'T',
#   'lastPrice': 7.2799,
#   'lastSize': 600,
#   'lastId': 'D',
#   'openPrice': 7.24,
#   'highPrice': 7.315,
#   'lowPrice': 7.23,
#   'bidTick': ' ',
#   'closePrice': 7.26,
#   'netChange': 0.0199,
#   'totalVolume': 138900,
#   'quoteTimeInLong': 1659728559741,
#   'tradeTimeInLong': 1659728390737,
#   'mark': 7.2799,
#   'exchange': 'a',
#   'exchangeName': 'AMEX',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0638,
#   'digits': 4,
#   '52WkHigh': 9.22,
#   '52WkLow': 6.3812,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.695,
#   'divYield': 9.57,
#   'divDate': '2022-08-11 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 7.2799,
#   'regularMarketLastSize': 6,
#   'regularMarketNetChange': 0.0199,
#   'regularMarketTradeTimeInLong': 1659728390737,
#   'netPercentChangeInDouble': 0.2741,
#   'markChangeInDouble': 0.0199,
#   'markPercentChangeInDouble': 0.2741,
#   'regularMarketPercentChangeInDouble': 0.2741,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'WHF': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '96524V106',
#   'assetSubType': '',
#   'symbol': 'WHF',
#   'description': 'WhiteHorse Finance, Inc. - Common Stock',
#   'bidPrice': 14.01,
#   'bidSize': 200,
#   'bidId': 'Q',
#   'askPrice': 14.08,
#   'askSize': 200,
#   'askId': 'Q',
#   'lastPrice': 14.01,
#   'lastSize': 100,
#   'lastId': 'Q',
#   'openPrice': 14.05,
#   'highPrice': 14.17,
#   'lowPrice': 13.99,
#   'bidTick': ' ',
#   'closePrice': 14.02,
#   'netChange': -0.01,
#   'totalVolume': 21739,
#   'quoteTimeInLong': 1659728365358,
#   'tradeTimeInLong': 1659728541117,
#   'mark': 14.01,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.3197,
#   'digits': 4,
#   '52WkHigh': 16.22,
#   '52WkLow': 12.35,
#   'nAV': 0.0,
#   'peRatio': 11.0155,
#   'divAmount': 1.42,
#   'divYield': 10.13,
#   'divDate': '2022-06-16 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 14.01,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.01,
#   'regularMarketTradeTimeInLong': 1659728541117,
#   'netPercentChangeInDouble': -0.0713,
#   'markChangeInDouble': -0.01,
#   'markPercentChangeInDouble': -0.0713,
#   'regularMarketPercentChangeInDouble': -0.0713,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'SMCI': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '86800U104',
#   'assetSubType': '',
#   'symbol': 'SMCI',
#   'description': 'Super Micro Computer, Inc. - Common Stock',
#   'bidPrice': 58.8,
#   'bidSize': 100,
#   'bidId': 'Y',
#   'askPrice': 58.91,
#   'askSize': 300,
#   'askId': 'Q',
#   'lastPrice': 58.84,
#   'lastSize': 100,
#   'lastId': 'D',
#   'openPrice': 58.5,
#   'highPrice': 60.31,
#   'lowPrice': 58.0,
#   'bidTick': ' ',
#   'closePrice': 59.13,
#   'netChange': -0.29,
#   'totalVolume': 484373,
#   'quoteTimeInLong': 1659728585588,
#   'tradeTimeInLong': 1659728571926,
#   'mark': 58.84,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0896,
#   'digits': 4,
#   '52WkHigh': 60.31,
#   '52WkLow': 34.11,
#   'nAV': 0.0,
#   'peRatio': 15.9,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 58.84,
#   'regularMarketLastSize': 1,
#   'regularMarketNetChange': -0.29,
#   'regularMarketTradeTimeInLong': 1659728571926,
#   'netPercentChangeInDouble': -0.4904,
#   'markChangeInDouble': -0.29,
#   'markPercentChangeInDouble': -0.4904,
#   'regularMarketPercentChangeInDouble': -0.4904,
#   'delayed': False,
#   'realtimeEntitled': True},
#  'RSSS': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '761025105',
#   'assetSubType': '',
#   'symbol': 'RSSS',
#   'description': 'Research Solutions, Inc - Common Stock',
#   'bidPrice': 1.81,
#   'bidSize': 200,
#   'bidId': 'Q',
#   'askPrice': 1.87,
#   'askSize': 500,
#   'askId': 'Q',
#   'lastPrice': 1.8039,
#   'lastSize': 200,
#   'lastId': 'Z',
#   'openPrice': 1.82,
#   'highPrice': 1.86,
#   'lowPrice': 1.8039,
#   'bidTick': ' ',
#   'closePrice': 1.81,
#   'netChange': -0.0061,
#   'totalVolume': 6092,
#   'quoteTimeInLong': 1659728548075,
#   'tradeTimeInLong': 1659717647657,
#   'mark': 1.81,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': False,
#   'shortable': False,
#   'volatility': 0.513,
#   'digits': 4,
#   '52WkHigh': 2.84,
#   '52WkLow': 1.69,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 1.8039,
#   'regularMarketLastSize': 2,
#   'regularMarketNetChange': -0.0061,
#   'regularMarketTradeTimeInLong': 1659717647657,
#   'netPercentChangeInDouble': -0.337,
#   'markChangeInDouble': 0.0,
#   'markPercentChangeInDouble': 0.0,
#   'regularMarketPercentChangeInDouble': -0.337,
#   'delayed': False,
#   'realtimeEntitled': True}}
