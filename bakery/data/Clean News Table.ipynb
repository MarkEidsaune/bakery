# %% [markdown]
# # News API
# https://newsapi.org/

# %% [markdown]
# Install modules

# %%
import sys
# !{sys.executable} -m pip install

# %% [markdown]
# Load modules

# %%
import os
import requests
import json
import pandas as pd
from cassandra.cluster import Cluster
from tqdm import tqdm
from datetime import datetime, date, timedelta

# %% [markdown]
# Set paths

# %%
base_path = os.path.join(os.path.expanduser('~'), 'bakery')
creds_path = os.path.join(base_path, 'news_api/creds.json')

# %% [markdown]
# Load credential file

# %%
with open(creds_path, 'rb') as f:
    data = f.read()
    creds = json.loads(data)

# %% [markdown]
# Connect to Cassandra cluster

# %%
cass_cluster = Cluster()
cass_session = cass_cluster.connect()

# %% [markdown]
# ##### Get News Table from Cassandra

# %% [markdown]
# Send request

# %%
endpoint = 'https://newsapi.org/v2/top-headlines/sources'
headers = {'Authorization' : creds['api_key']}
params = {'language': 'en'}

r = requests.get(endpoint, headers=headers, params=params)

# %%
r.json()
# Out:
# {'status': 'ok',
#  'totalResults': 267,
#  'articles': [{'source': {'id': 'associated-press',
#     'name': 'Associated Press'},
#    'author': 'By FRANK BAJAK - Associated Press',
#    'title': 'Twitter breach exposed anonymous account owners',
#    'description': 'Twitter says vulnerability in its software that exposed an undetermined number of owners of anonymous accounts to potential identity compromise last year was apparently exploited by a malicious actor. It did not confirm a report that data on 5.4 million…',
#    'url': 'https://apnews.com/27382aa1537c97e6266f8a7d9ad977d6',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/custom/image/00f1ee32-f2d0-11e6-9926-f7249dbfe53a.jpg?resize=600%2C315',
#    'publishedAt': '2022-08-05T21:56:49Z',
#    'content': "A vulnerability in Twitter's software that exposed an undetermined number of owners of anonymous accounts to potential identity compromise last year was apparently exploited by a malicious actor, the… [+2676 chars]"},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By DYLAN LOVAN - Associated Press',
#    'title': 'Breonna Taylor supporters relieved by charges against police',
#    'description': 'Louisville activists who put in long hours protesting the death of Breonna Taylor at the hands of police say they felt relief this week when federal officials charged four officers. They say the new civil rights charges turned the tables…',
#    'url': 'https://apnews.com/ad3b4ee8e60e6f8920e340bf3655f3ed',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/4/89/48962849-4aae-507d-9ea1-2cdc2bd22a0b/62ed9682ab4c5.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T21:50:52Z',
#    'content': 'By DYLAN LOVAN - Associated Press\r\nLOUISVILLE, Ky. (AP) Louisville activists put in long hours on phones and in the streets, working tirelessly to call for arrests in the fatal police shooting of Bre… [+5584 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By The Associated Press',
#    'title': 'AP Week in Pictures: Europe and Africa',
#    'description': 'July 29 - Aug. 4, 2022',
#    'url': 'https://apnews.com/0f6ae411ed339d06b9741db7618f5f06',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/4/85/4850f400-8ed0-5b1f-8494-53013b706782/62ecbc9f7bef6.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T06:18:17Z',
#    'content': 'Lilia Panchenko is pulled away by her husband, Anatolii, right, as she says her final goodbye to their son, Oleh, along with his daughter, Ruslana, left, before his casket is covered during his buria… [+185 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'AP',
#    'title': 'China announces unspecified sanctions on U.S. House Speaker Nancy Pelosi for her visit to Taiwan',
#    'description': 'China announces unspecified sanctions on U.S. House Speaker Nancy Pelosi for her visit to Taiwan.',
#    'url': 'https://apnews.com/01484be197eedace2ebdaedbe669ec84',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/custom/image/00f1ee32-f2d0-11e6-9926-f7249dbfe53a.jpg?resize=600%2C315',
#    'publishedAt': '2022-08-05T08:26:53Z',
#    'content': 'Russias state-owned natural gas corporation says it has halted shipments to Latvia because of contract violations. In a brief statement, gas giant Gazprom said the shipments were stopped because Latv… [+488 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'Associated Press',
#    'title': 'News reports: Musk countersuit accuses Twitter of fraud',
#    'description': 'Elon Musk accused Twitter of fraud in a countersuit over his aborted $44 billion deal for the social media company, which he said held back necessary information and misled his team about its true user base. According to The Washington…',
#    'url': 'https://apnews.com/933f52cf58fea145e71f1112563951d4',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/2/48/24845185-e7cf-56af-8a64-af5fd6b58840/62ec4fbf807b8.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T10:58:01Z',
#    'content': 'Elon Musk accused Twitter of fraud in a countersuit over his aborted $44 billion deal for the social media company, which he said held back necessary information and misled his team about its true us… [+1564 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'AP, KMGH-TV',
#    'title': 'Aurora police: Man doused 2 with gas in possible hate crime',
#    'description': 'Police in a Colorado suburb say they’re looking for a man who doused two customers with gasoline at a fueling station after confronting them because they were speaking Spanish and “don’t belong here.” Aurora police say the man looked for…',
#    'url': 'https://apnews.com/dfff6a466c4aec234b3a0c451087371b',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/custom/image/00f1ee32-f2d0-11e6-9926-f7249dbfe53a.jpg?resize=600%2C315',
#    'publishedAt': '2022-08-05T03:29:59Z',
#    'content': 'AURORA, Colo. (AP) Police in suburban Denver say theyre looking for a man who doused two customers with gasoline at a fueling station after confronting them because they were speaking Spanish and don… [+1442 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'AP',
#    'title': "Wayne Steele wins Democratic nomination for U.S. House in Tennessee's 4th Congressional District.",
#    'description': "Wayne Steele wins Democratic nomination for U.S. House in Tennessee's 4th Congressional District.",
#    'url': 'https://apnews.com/5da4f0087f4d4dcf9bf86d5b08890033',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/custom/image/00f1ee32-f2d0-11e6-9926-f7249dbfe53a.jpg?resize=600%2C315',
#    'publishedAt': '2022-08-05T02:42:15Z',
#    'content': 'Russias state-owned natural gas corporation says it has halted shipments to Latvia because of contract violations. In a brief statement, gas giant Gazprom said the shipments were stopped because Latv… [+488 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By BOB CHRISTIE - Associated Press',
#    'title': 'Democrat Adrian Fontes wins Arizona secretary of state race',
#    'description': 'Former Maricopa County Recorder Adrian Fontes has won the Democratic nomination for Arizona secretary of state. Additional returns released Thursday night show Fontes is so far ahead of House Minority Leader Reginald Bolding that remaining ballots give Boldin…',
#    'url': 'https://apnews.com/2e6a73e3025cfe5ef18e41e6d1eba96b',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/7/2f/72fd075a-b6fb-56d1-b224-22a66e1ff980/62e75357a094c.image.jpg?crop=1175%2C617%2C0%2C573&resize=1175%2C617&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T02:31:41Z',
#    'content': 'By BOB CHRISTIE - Associated Press\r\nPHOENIX (AP) Former Maricopa County Recorder Adrian Fontes has won the Democratic nomination for Arizona secretary of state and the right to take on a supporter of… [+2122 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By SCOTT BAUER - Associated Press',
#    'title': "Trump ally takes on Walker protégé in Wis. governor's race",
#    'description': "Republican hopes to reclaim a crucial governor’s seat in swing-state Wisconsin this year long appeared to rest on Rebecca Kleefisch. She's a former TV news anchor who spent eight years as former Gov. Scott Walker’s heir apparent and vowed to…",
#    'url': 'https://apnews.com/d7bc3d0810cf54bafc699fc881786b46',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/1/b1/1b1f2f12-1c92-57a6-a808-4c686a65dc49/62ec9949cd2e3.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T04:08:11Z',
#    'content': 'By SCOTT BAUER - Associated Press\r\nMADISON, Wis. (AP) Republican hopes to reclaim a crucial governors seat in swing-state Wisconsin this year long appeared to rest on Rebecca Kleefisch, a former TV n… [+6921 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By FIRDIA LISNAWATI - Associated Press',
#    'title': 'Indonesia arrests 3 foreigners for drug distribution in Bali',
#    'description': 'Authorities in Indonesia arrested three foreigners for distributing cocaine on the Indonesian resort island of Bali at the end of July. Officers from the National Narcotics Agency seized almost 2 pounds of cocaine from the three suspects, who are identified…',
#    'url': 'https://apnews.com/127097f67154f226c0438e9003a3c98e',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/3/97/397074d3-748c-540e-b75a-24184af7068f/62ece340b4382.image.jpg?crop=1777%2C933%2C0%2C116&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T09:05:40Z',
#    'content': 'By FIRDIA LISNAWATI - Associated Press\r\nAuthorities in Indonesia arrested three foreigners for distributing cocaine on the Indonesian resort island of Bali at the end of July.\r\nOfficers from the Nati… [+2538 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By SAMYA KULLAB - Associated Press',
#    'title': "In Baghdad's Sadr City, cleric's support underpins protests",
#    'description': "Residents of the impoverished Baghdad suburb of Sadr City say they they support an influential Shiite cleric who called on thousands of his followers to storm Iraq's parliament. Khalil Ibrahim has four sons participating in the parliament sit-in he told…",
#    'url': 'https://apnews.com/25267dd5e182ee4a26ede6b499963998',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/b/16/b166d6f1-d1f2-535f-9c49-e4a62babea39/62ecbcaae651e.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T06:15:54Z',
#    'content': 'By SAMYA KULLAB - Associated Press\r\nBAGHDAD (AP) Khalil Ibrahims four sons are among thousands of followers of an influential Shiite cleric staging a sit-in outside Iraqs parliament after storming th… [+6320 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By ARLEIGH RODGERS - Associated Press/Report for America',
#    'title': 'Indiana House passes spending, inflation relief bill',
#    'description': 'The Indiana House has approved a bill that includes $200 rebate payments from the state’s surging budget surplus. Though less than Republican Gov. Eric Holcomb’s initially proposed $225 refunds, the bill approved Friday represents a concession from GOP senato…',
#    'url': 'https://apnews.com/cda13cbcc01c6181788bee15505e13da',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/7/df/7df21b9d-e531-5cdc-b983-e19936d007db/62eadaf16fdda.image.jpg?crop=1662%2C873%2C0%2C187&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T14:49:14Z',
#    'content': 'By ARLEIGH RODGERS - Associated Press/Report for America\r\nINDIANAPOLIS (AP) The Indiana House approved a bill Friday that would provide $200 rebate payments from the states surging budget surplus.\r\nT… [+2435 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'The Associated Press',
#    'title': 'Lady A postpones tour as Charles Kelley focuses on sobriety',
#    'description': 'Grammy-winning country trio Lady A is postponing its tour this year as band member Charles Kelley focuses on sobriety. The group said in a social media post that the band would be “taking time with the support their families and…',
#    'url': 'https://apnews.com/92cbafa444646d4be333adacec07cf73',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/4/f2/4f299f9f-8dc5-5a76-b28e-5cd1fdf25a64/62ed3b096f676.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T15:22:18Z',
#    'content': 'NASHVILLE, Tenn. (AP) The Grammy-winning country trio Lady A has announced that its upcoming tour is being postponed to allow band member Charles Kelley time to focus on his sobriety.\r\nThe group was … [+700 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By JEFF AMY - Associate Press',
#    'title': 'Judge rules Georgia must end statewide PSC elections',
#    'description': 'A federal judge has ruled that Georgia’s statewide election of its five public service commissioners illegally dilutes Black voting power. The judge on Friday ordered the state to not prepare ballots for two races that had been scheduled in November.…',
#    'url': 'https://apnews.com/8b2b2560a9c530c5869f877513062ae6',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/custom/image/00f1ee32-f2d0-11e6-9926-f7249dbfe53a.jpg?resize=600%2C315',
#    'publishedAt': '2022-08-05T15:44:50Z',
#    'content': "ATLANTA (AP) A federal judge ruled Friday that Georgia's statewide election of its five public service commissioners illegally dilutes Black voting power, ordering the state to not prepare ballots fo… [+4121 chars]"},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'AP',
#    'title': 'Indiana man gets life in killing of girlfriend, 3 kids',
#    'description': 'A Fort Wayne man will spend the rest of his life in prison after a judge ordered that he serve four life sentences without the possibility of parole for the 2021 slayings of a woman and her three young children.…',
#    'url': 'https://apnews.com/3bb83ec4ddd157e083e2f62127e1b167',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/custom/image/00f1ee32-f2d0-11e6-9926-f7249dbfe53a.jpg?resize=600%2C315',
#    'publishedAt': '2022-08-05T20:48:30Z',
#    'content': 'FORT WAYNE, Ind. (AP) An Indiana man convicted of killing his girlfriend and her three young children was sentenced Friday to four life sentences without the possibility of parole.\r\nThe sentence impo… [+1068 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By SARAH RANKIN - Associated Press',
#    'title': "Virginia regulators OK Dominion's planned offshore wind farm",
#    'description': 'State regulators have approved an application from Dominion Energy Virginia to build an enormous offshore wind farm off the coast of Virginia Beach and recover the cost from ratepayers. The State Corporation Commission issued its order in the case Friday.…',
#    'url': 'https://apnews.com/796b1256c2bedee36abc258e46eaefc4',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/8/0a/80a58941-3a92-5c07-840d-5dc64cc7fce9/62ed8910e7bca.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T21:16:02Z',
#    'content': 'By SARAH RANKIN - Associated Press\r\nRICHMOND, Va. (AP) State regulators on Friday approved an application from Dominion Energy Virginia to build an enormous offshore wind farm off the coast of Virgin… [+4619 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By LEAH WILLINGHAM and BRYNN ANDERSON',
#    'title': 'Kentucky flood survivors turn to grim task: burying the dead',
#    'description': "Angel Campbell should have been looking through photo albums and eating soup beans in her grandmother's living room this week. Now the living room is gone and so is her grandmother. At least 37 people died as massive floods roared…",
#    'url': 'https://apnews.com/5d3a9c01815db51aa14eb79eaa67ea28',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/a/45/a45afb7f-8084-56a7-8bae-9448bae323ed/62ed492a7ee5c.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T16:23:58Z',
#    'content': 'By LEAH WILLINGHAM and BRYNN ANDERSON\r\nCHAVIES, Ky. (AP) Angel Campbell should have been sitting in her usual chair in her grandmothers living room this week, looking through her old photo albums and… [+5997 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'AP',
#    'title': 'New Mexico authorities investigate killings of 3 Muslim men',
#    'description': "Police in New Mexico's largest city are investigating whether the ambush shooting deaths of three Muslim men over the past nine months could be connected. Albuquerque police have confirmed that detectives and federal law enforcement officers are looking for p…",
#    'url': 'https://apnews.com/14681c001d428987e92140ab93c5ea25',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/custom/image/00f1ee32-f2d0-11e6-9926-f7249dbfe53a.jpg?resize=600%2C315',
#    'publishedAt': '2022-08-05T23:16:03Z',
#    'content': 'ALBUQUERQUE, N.M. (AP) Police in New Mexicos largest city are trying to determine if the ambush shooting deaths of three Muslim men over the past nine months could be connected.\r\nAlbuquerque police h… [+2508 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By DAVID PORTER - Associated Press',
#    'title': 'GoFundMe scammer who used story of homeless vet gets 5 years',
#    'description': "A New Jersey man who made up a story about a homeless veteran helping out his then-girlfriend and used the tale to solicit $400,000 in online donations has been sentenced to prison. A judge in Burlington County sentenced Mark D'Amico…",
#    'url': 'https://apnews.com/9ac4d4cca7fc495cd4dc412478849f36',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/b/ea/beaa2648-1b46-5637-80df-3778accca2b7/62ed967f7e8e7.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T21:59:55Z',
#    'content': 'By DAVID PORTER - Associated Press\r\nA New Jersey man who made up a story about a homeless veteran helping out his then-girlfriend and used the tale to solicit more than $400,000 in online donations w… [+2339 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By LISA MASCARO - AP Congressional Correspondent',
#    'title': "Sinema gives her nod, and influence, to Democrats' big bill",
#    'description': 'Sen. Joe Manchin sealed the deal reviving President Joe Biden’s big economic, health care and climate bill. But it was another Democratic senator, Kyrsten Sinema of Arizona, who quietly shaped the final product. Democrats pushed ahead Friday on the estimated…',
#    'url': 'https://apnews.com/c0d40a6f2490b2613a690995daca7e11',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/1/fb/1fb5b3c6-4ad9-5f41-9e02-462997507db8/62ed76e1229b0.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T19:46:44Z',
#    'content': 'By LISA MASCARO - AP Congressional Correspondent\r\nWASHINGTON (AP) Sen. Joe Manchin sealed the deal reviving President Joe Bidens big economic, health care and climate bill. But it was another Democra… [+7561 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By MICHAEL BALSAMO and MICHAEL R. SISAK - Associated Press',
#    'title': 'Senate to hold hearing on crisis-plagued federal prisons',
#    'description': 'The chairman of the Senate Judiciary Committee says he plans to hold an oversight hearing on the crisis-plagued federal Bureau of Prisons after The Associated Press reported that the agency is keeping its embattled ex-director on the payroll as an…',
#    'url': 'https://apnews.com/bd7701e443e9ff5409e154e5f2343896',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/roanoke.com/content/tncms/assets/v3/editorial/0/04/004d9796-8d67-53ed-9caf-8881be4ce0f7/62eda49da5875.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T22:53:22Z',
#    'content': 'By MICHAEL BALSAMO and MICHAEL R. SISAK - Associated Press\r\nWASHINGTON (AP) The chairman of the Senate Judiciary Committee said Friday he plans to hold an oversight hearing on the crisis-plagued fede… [+4208 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By PAUL WISEMAN - AP Economics Writer',
#    'title': 'As recession fears grow, strong US hiring is likely slowing',
#    'description': 'The American job market has defied raging inflation, rising interest rates, growing recession fears. Month after month, U.S. employers just kept adding hundreds of thousands of workers. But now economists worry that signs of weakness are starting to turn up…',
#    'url': 'https://apnews.com/4895f1aa41fbe904400df8261446b737',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/e/8a/e8af86cd-dbef-516d-80f6-09547d825a7b/62ecc714aae96.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T07:01:06Z',
#    'content': 'By PAUL WISEMAN - AP Economics Writer\r\nWASHINGTON (AP) The American job market has defied raging inflation, rising interest rates, growing recession fears. Month after month, U.S. employers just kept… [+8101 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'AP',
#    'title': "NFL's preseason Hall of Fame game delayed due to weather",
#    'description': 'The start of the Hall of Fame game between the Jacksonville Jaguars and the Las Vegas Raiders on Thursday night was delayed due to severe weather in the area.',
#    'url': 'https://apnews.com/41717ea947c24e602fa7777ca836ee50',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/8/1c/81cd8cfe-878d-5f46-9d23-244e54d51c64/62ec6bf1f02e1.image.jpg?crop=1763%2C926%2C0%2C125&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T00:44:53Z',
#    'content': 'CANTON, Ohio (AP) The start of the Hall of Fame game between the Jacksonville Jaguars and the Las Vegas Raiders on Thursday night was delayed due to severe weather in the area.\r\nFans were told to see… [+488 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'AP',
#    'title': 'Tom Kim going places in a hurry, among leaders at Wyndham',
#    'description': 'Joohyung Kim began the Wyndham Championship with a quadruple bogey. Now the 20-year-old South Korean who goes by “Tom” is among the early leaders. Kim has made 14 birdies at Sedgefield Country Club since that 8 on his first hole.…',
#    'url': 'https://apnews.com/1a89bd1b68a201c8abf09fd9c0c30b6b',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/8/72/8728cbc5-bcb6-5fcc-801b-91cf12fe6926/62ed639470a95.image.jpg?crop=1723%2C905%2C0%2C148&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T18:23:57Z',
#    'content': "GREENSBORO, N.C. (AP) Joohyung Tom Kim began the Wyndham Championship with a quadruple bogey on his first hole and wasn't the least bit bothered. The kid seems to be going places in a hurry.\r\nAlready… [+4787 chars]"},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'AP',
#    'title': 'Cardinals RBs coach facing domestic battery charges',
#    'description': 'Arizona Cardinals running backs coach James Saxon has been charged with two counts of domestic battery in Indianapolis stemming from an alleged incident in May. One of the counts includes a charge of domestic battery committed in the presence of…',
#    'url': 'https://apnews.com/5a067c8ab8f12510d54bd3c219af2d56',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/3/39/3391a8d9-f73e-5735-a3a3-c7d89cf3db85/62ed73703a614.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T19:29:54Z',
#    'content': 'GLENDALE, Ariz. (AP) Arizona Cardinals running backs coach James Saxon has been charged in Indianapolis with two counts of domestic battery stemming from an alleged incident in May.\r\nOne of the count… [+2716 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By TOM KRISHER - AP Auto Writer',
#    'title': 'US agency probes Tesla crashes that killed 2 motorcyclists',
#    'description': 'Two crashes involving Teslas apparently running on Autopilot are drawing scrutiny from federal regulators and point to a potential new hazard on U.S. freeways: The partially automated vehicles may not stop for motorcycles. The National Highway Traffic Safety …',
#    'url': 'https://apnews.com/12ba38bd863e2b128a8e2914179049e0',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/f/3e/f3ea4c10-6675-50c1-a7f6-fdd019ef6c42/62ed4240d5cd4.image.jpg?crop=844%2C443%2C0%2C528&resize=844%2C443&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T16:08:08Z',
#    'content': 'By TOM KRISHER - AP Auto Writer\r\nDETROIT (AP) Two crashes involving Teslas apparently running on Autopilot are drawing scrutiny from federal regulators and point to a potential new hazard on U.S. fre… [+6292 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By BRIAN DULIK - Associated Press',
#    'title': 'Pro Bowl guard Teller aiming for Browns turnaround',
#    'description': 'Right guard Wyatt Teller firmly established himself as one of the NFL’s top offensive linemen last season, earning his first Pro Bowl selection. The Cleveland Browns rewarded him with a $56.8 million, four-year contract extension. Accolades and big money only…',
#    'url': 'https://apnews.com/66795c6dd7296bef0636f93869a1c724',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/4/33/43304c2e-3854-529d-98e7-ac61eccc9c2e/62e45bf686e61.image.jpg?crop=1764%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T21:32:56Z',
#    'content': "By BRIAN DULIK - Associated Press\r\nBEREA, Ohio (AP) Right guard Wyatt Teller firmly established himself as one of the NFL's top offensive linemen last season, earning his first Pro Bowl selection.\r\nT… [+4327 chars]"},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By PAUL NEWBERRY - AP Sports Columnist',
#    'title': 'Column: NFL lets bad boy owners get off with slap on wrist',
#    'description': 'After Donald Sterling’s racist ramblings were exposed to the world, the NBA moved quickly to banish him from the league. Sure, the forced sale of the Los Angeles Clippers made Sterling even richer, but it sent a clear signal that…',
#    'url': 'https://apnews.com/b87199aaec98461080acf768a46e1081',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/d/08/d0840f7d-9b7a-53fb-974c-18f6b78deee2/62e966a4c322c.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T20:20:32Z',
#    'content': "By PAUL NEWBERRY - AP Sports Columnist\r\nAfter Donald Sterling's racist ramblings were exposed to the world, the NBA moved quickly to banish him from the league.\r\nSure, the forced sale of the Los Ange… [+7267 chars]"},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'AP',
#    'title': 'US stocks falling after red-hot jobs report; Warner -15%',
#    'description': 'Stocks are opening lower on Wall Street Friday following much stronger than expected hiring data from the Labor Department. The S&P 500 is off 0.8% at the opening bell and the Nasdaq is down by more than a percent. The…',
#    'url': 'https://apnews.com/f8f9dcd914b1966896f410b0556e392a',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/7/5a/75a773d8-edcd-57b5-9b70-f6e85c01759f/62ed260309ce2.image.jpg?crop=1763%2C926%2C0%2C125&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T13:48:18Z',
#    'content': 'NEW YORK (AP) Stocks are opening lower on Wall Street Friday following much stronger than expected hiring data from the Labor Department. The S&amp;P 500 is off 0.8% at the opening bell and the Nasda… [+4379 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By ROB MAADDI - AP Pro Football Writer',
#    'title': 'Raiders give McDaniels happy homecoming, beat Jaguars 27-11',
#    'description': 'Josh Jacobs and rookie Zamir White ran well on a rain-soaked field and the Raiders routed Jacksonville 27-11 in the Hall of Fame game Thursday night, spoiling coach Doug Pederson’s first game with the Jaguars. Derek Carr and Davante Adams…',
#    'url': 'https://apnews.com/1ef4e7063afad61d250458a4e6e0b08c',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/6/6f/66fad378-e5dd-50a1-9b7c-7f61d7e85db8/62ec95c56ec12.image.jpg?crop=1763%2C926%2C0%2C125&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T03:43:53Z',
#    'content': 'By ROB MAADDI - AP Pro Football Writer\r\nCANTON, Ohio (AP) The Las Vegas Raiders gave coach Josh McDaniels a successful homecoming in his debut on their sideline.\r\nJosh Jacobs, rookie Zamir White and … [+5386 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By AMANDA SEITZ - Associated Press',
#    'title': 'Meta trims election misinformation efforts as midterms loom',
#    'description': 'Facebook owner Meta is quietly curtailing some safeguards designed to thwart voting misinformation or foreign interference in elections even as the U.S. midterms approach. The pivot is raising alarm about Meta’s priorities and how some might exploit the world…',
#    'url': 'https://apnews.com/0ab5375951df71093d240a6631edb9da',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/b/2e/b2e9f5d5-b034-59b4-ba53-50de6d2da5f9/62ecedc01a867.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T10:07:40Z',
#    'content': 'By AMANDA SEITZ - Associated Press\r\nWASHINGTON (AP) Facebook owner Meta is quietly curtailing some of the safeguards designed to thwart voting misinformation or foreign interference in U.S. elections… [+9820 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By RISHI LEKHI and SHONAL GANGULY - Associated Press',
#    'title': 'Indian police block opposition protests over price increases',
#    'description': 'Indian police have detained dozens of lawmakers from the opposition Congress party, including key leader Rahul Gandhi, as they attempted to march to the president’s palace and prime minister’s residence to protest soaring food and fuel prices and an increase…',
#    'url': 'https://apnews.com/18671e82025e9ccbb411441e63744063',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/c/ef/cefdcb77-5433-543e-8bee-4e153a615c4c/62ecedc0cd4b9.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T09:57:46Z',
#    'content': 'By RISHI LEKHI and SHONAL GANGULY - Associated Press\r\nNEW DELHI (AP) Indian police detained dozens of lawmakers from the opposition Congress party, including key leader Rahul Gandhi, as they attempte… [+3760 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'AP',
#    'title': "Chun takes halfway lead at Women's British Open",
#    'description': "In Gee Chun is making another strong run at a major. The South Korean golfer took the halfway lead at the Women’s British Open after a 5-under 66 in the second round. She's in position to challenge for a second…",
#    'url': 'https://apnews.com/74c760f56e773ad3a7a3ec545c8d7e0e',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/6/f6/6f688dd8-1e2c-59d8-aec6-05b2787f1232/62ed70cf19dc8.image.jpg?crop=1247%2C655%2C0%2C503&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T19:20:23Z',
#    'content': "MUIRFIELD, Scotland (AP) In Gee Chun is making another strong run at a major.\r\nThe South Korean golfer took the halfway lead at the Women's British Open after a 5-under 66 in the second round on Frid… [+3801 chars]"},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By DENNIS WASZAK Jr. - AP Pro Football Writer',
#    'title': "Mims motivated to be 'on top' of Jets' receiver depth chart",
#    'description': 'Denzel Mims was the New York Jets’ exciting new playmaker two summers ago as a potential game-changing wide receiver for years to come. A lot has happened since. And not a lot good. The 2020 second-round pick out of Baylor…',
#    'url': 'https://apnews.com/94db990121e92e46ba7f33ccda280f20',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/5/dd/5dda9936-676f-565d-a218-bd0b4792d9e0/62ed7370c64d1.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T19:30:52Z',
#    'content': "By DENNIS WASZAK Jr. - AP Pro Football Writer\r\nFLORHAM PARK, N.J. (AP) Denzel Mims was the New York Jets' exciting new playmaker two summers ago, a potential game-changing wide receiver for years to … [+5839 chars]"},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By FRED GOODALL - AP Sports Writer',
#    'title': 'Injured WR Godwin back on practice field for Buccaneers',
#    'description': 'Seven months after undergoing knee surgery, Tampa Bay Buccaneers receiver Chris Godwin is back in pads on the practice field. The sixth-year pro who signed a three-year, $60 million contract this offseason worked out in full uniform at training camp.…',
#    'url': 'https://apnews.com/53a82f46de128963b6e89b3d94c57d6e',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/c/d1/cd1a7c5f-5660-59e6-a9bc-5d50b15d2c94/62ed8500966fe.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T20:42:45Z',
#    'content': 'By FRED GOODALL - AP Sports Writer\r\nTAMPA, Fla. (AP) Seven months after undergoing knee surgery, Tampa Bay Buccaneers receiver Chris Godwin is back in pads on the practice field.\r\nGodwin, who signed … [+3076 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By ROB MAADDI - AP Pro Football Writer',
#    'title': "Pro Football Hall of Fame recognizes women's impact",
#    'description': 'A 15-year-old boy made his way through the The Pro Football Hall of Fame museum, checking out the memorabilia and bronze busts before stopping to take a picture of Jen Welter’s blue-and-pink jersey to send to his younger sister. Welter…',
#    'url': 'https://apnews.com/7a77452080398234469c1305b6772ff1',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/b/33/b334e283-c3b3-541e-9fcc-9c34347d364f/62ed88653e4b7.image.jpg?crop=1662%2C873%2C0%2C187&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T20:49:56Z',
#    'content': 'By ROB MAADDI - AP Pro Football Writer\r\nCANTON, Ohio (AP) A 15-year-old boy made his way through the the Pro Football Hall of Fame museum on Friday, checking out the memorabilia and bronze busts befo… [+4498 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By SCHUYLER DIXON - AP Pro Football Writer',
#    'title': "Barr could help young Cowboys star Parsons' pursuit of sacks",
#    'description': "The signing of free agent linebacker Anthony Barr could nudge young star Micah Parsons closer to being primarily a pass rusher for the Dallas Cowboys. The club also had depth in mind with the addition of Barr, who's a four-time…",
#    'url': 'https://apnews.com/2f048704cd80f3220acf12a470507d23',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/d/4d/d4d29a98-29e3-52e9-8451-e1971e14f7ad/62ed968f242f7.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T22:03:51Z',
#    'content': 'By SCHUYLER DIXON - AP Pro Football Writer\r\nOXNARD, Calif. (AP) The signing of free agent linebacker Anthony Barr could nudge young star Micah Parsons closer to being primarily a pass rusher for the … [+5312 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By TIM BOOTH - AP Sports Writer',
#    'title': 'Seahawks hope RB room proves to be more than Rashaad Penny',
#    'description': 'Keeping their running backs healthy for an entire season has been an issue for the Seattle Seahawks. So while the Seahawks are going into this season with the intention of using Rashaad Penny as their featured back, it seems more…',
#    'url': 'https://apnews.com/a3cf7a84cb43e2bda0ba9f269c72c8bf',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/3/9a/39a417bf-4cc9-5b75-b4c8-0afc36256a61/62eda14228872.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T22:38:16Z',
#    'content': 'By TIM BOOTH - AP Sports Writer\r\nRENTON, Wash. (AP) As recent years have shown, keeping their running backs healthy for an entire season has been an issue for the Seattle Seahawks.\r\nSo while the Seah… [+4716 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By CHRISTOPHER RUGABER - AP Economics Writer',
#    'title': 'EXPLAINER: How do we know when a recession has begun?',
#    'description': 'The U.S. economy has contracted for two straight quarters, intensifying fears that it is on the cusp of a recession, if not already in one, barely two years after the pandemic downturn officially ended. Six months of contraction is a…',
#    'url': 'https://apnews.com/d2fd0bbc09fbe98d8fdb4840be29e826',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/1/88/1887ddba-3ef9-5ab7-b1c8-855bd2d1a8fe/62ed0f1d1860c.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T10:17:00Z',
#    'content': 'By CHRISTOPHER RUGABER - AP Economics Writer\r\nWASHINGTON (AP) The U.S. economy has contracted for two straight quarters, intensifying fears that the nation is on the cusp of a recession if not alread… [+9800 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By ELAINE KURTENBACH - AP Business Writer',
#    'title': 'Pacific rim economies in doldrums, sapped by inflation, war',
#    'description': 'Economies in the Asia-Pacific are forecast to hit the doldrums this year as decades-high inflation and the war in Ukraine add to uncertainty and the aftereffects of the pandemic. A report on Pacific Rim economies by the Asia Pacific Economic…',
#    'url': 'https://apnews.com/b6bb5cc8756185206b14b73e5ab3bd87',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/c/f3/cf3e7fce-d1d8-512e-a0d5-bf181406ad37/62ecf4ca25b9d.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T10:25:03Z',
#    'content': 'By ELAINE KURTENBACH - AP Business Writer\r\nBANGKOK (AP) Economies in the Asia-Pacific are forecast to hit the doldrums this year as decades-high inflation and the war in Ukraine compound geopolitical… [+4721 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By GREG BEACHAM - AP Sports Writer',
#    'title': 'Rams\' McVay calls Stafford\'s elbow pain "abnormal" for a QB',
#    'description': 'Coach Sean McVay says Matthew Stafford’s continuing elbow pain is abnormal for a football player, and the Los Angeles Rams are trying to determine whether it will hamper their starting quarterback in the regular season. Stafford has been throwing in…',
#    'url': 'https://apnews.com/851425df674c709493cf077f7cbd4a84',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/0/dc/0dcd4019-552c-5544-9310-aa4423beea47/62ec6f4d71cfc.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T01:01:00Z',
#    'content': "By GREG BEACHAM - AP Sports Writer\r\nCoach Sean McVay says Matthew Stafford's continuing elbow pain is unusual for a football player, and the Los Angeles Rams are trying to determine whether it will h… [+3909 chars]"},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'AP',
#    'title': 'Mall of America to reopen following shooting and lockdown',
#    'description': 'The Mall of America is expected to reopen Friday, a day after someone opened fire inside the suburban Minneapolis shopping complex, sending shoppers running for cover. Bloomington police say no one was struck by the gunfire Thursday afternoon and they…',
#    'url': 'https://apnews.com/9666f27612bf80745b256ce53f6a04d4',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/e/98/e98db0c8-f07c-5ce0-a9cb-533b60d5d7de/62ed1ef245517.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T13:19:56Z',
#    'content': 'BLOOMINGTON, Minn. (AP) The Mall of America is expected to reopen Friday as police continue to search for an individual who fired gunshots inside the suburban Minneapolis shopping complex.\r\nBloomingt… [+2758 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By TERESA M. WALKER - AP Pro Football Writer',
#    'title': 'Titans patient as QB Malik Willis makes jump from Liberty',
#    'description': 'Malik Willis is experiencing some growing pains as the Tennessee Titans rookie works through his first NFL training camp. Willis has completed some nice passes and gotten the chance to run plays with the second-team offense. He took a sack…',
#    'url': 'https://apnews.com/fb847f6ddad265ea17fdf285c93914ea',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/7/5d/75d7a796-df32-5ca6-a5b0-6f4305daf9af/62e2f2126f649.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T19:03:25Z',
#    'content': 'By TERESA M. WALKER - AP Pro Football Writer\r\nNASHVILLE, Tenn. (AP) Malik Willis is experiencing some growing pains as the Tennessee Titans rookie works through his first training camp.\r\nWillis threw… [+4760 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By The Associated Press',
#    'title': 'Storms ground US air travelers as airlines cancel flights',
#    'description': 'Thunderstorms on the East Coast are causing travel headaches for tens of thousands of airline passengers. Airlines canceled more than 1,100 flights in the U.S. by midafternoon Friday. The highest numbers of canceled flights were at the three major airports…',
#    'url': 'https://apnews.com/6734833a2afdb36ecbdec1be18b702d8',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/8/76/876360ad-3ba3-561e-b084-5059c41f348f/62ed76d64d214.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T19:38:18Z',
#    'content': 'Tens of thousands of flyers had their travel plans upended Friday after airlines canceled more than 1,100 flights for a second straight day because of thunderstorms hitting the East Coast.\r\nThe New Y… [+3088 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By ROB MAADDI - AP Pro Football Writer',
#    'title': 'Union files brief replying to NFL’s appeal in Watson case',
#    'description': 'The NFL Players Association has filed a brief replying to the league’s appeal in Deshaun Watson’s discipline case. Former New Jersey Attorney General Peter C. Harvey now has the necessary paperwork to issue a ruling. Harvey was selected by NFL…',
#    'url': 'https://apnews.com/1fd9173e75aff25ecb0d5bfdacb56a53',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/b/17/b179a07d-590d-5965-8084-f33ab2b67c02/62ead7e430a80.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T22:24:51Z',
#    'content': 'By ROB MAADDI - AP Pro Football Writer\r\nCANTON, Ohio (AP) The NFL Players Association has filed a brief replying to the leagues appeal in Deshaun Watsons discipline case.\r\nFormer New Jersey Attorney … [+4339 chars]'},
#   {'source': {'id': 'associated-press', 'name': 'Associated Press'},
#    'author': 'By JOE REEDY - AP Sports Writer',
#    'title': 'JC Jackson quickly fitting into new-look Chargers defense',
#    'description': 'New Chargers cornerback J.C. Jackson is proving to be a quick study of the Los Angeles defense. The 26-year-old has been making life difficult for wide receivers during practices. The Chargers signed him as a free agent to shore up…',
#    'url': 'https://apnews.com/cefc7f6f2157732cbad08600c1bdcf7b',
#    'urlToImage': 'https://bloximages.newyork1.vip.townnews.com/stltoday.com/content/tncms/assets/v3/editorial/0/33/033bfe58-0661-58c7-ba35-bb452ff4682a/62edaf6c3b23e.image.jpg?crop=1763%2C926%2C0%2C124&resize=1200%2C630&order=crop%2Cresize',
#    'publishedAt': '2022-08-05T23:45:04Z',
#    'content': 'By JOE REEDY - AP Sports Writer\r\nCOSTA MESA, Calif. (AP) Less than two weeks into training camp, J.C. Jackson is proving to be a quick study of the Los Angeles Chargers defense.\r\nThe 26-year-old corn… [+5075 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Gabriela Sá Pessoa, Marina Lopes',
#    'title': 'Brazil gets tough on Crackland, and the drug market spreads',
#    'description': 'The São Paulo drug market is one of the world’s oldest and largest. Now police pressure is pushing it beyond its traditional boundaries.',
#    'url': 'https://www.washingtonpost.com/world/2022/08/05/brazil-crackland-sao-paulo-drug-market/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/A22OPKATNQI63BECA3A4QTHI6I.jpg&w=1440',
#    'publishedAt': '2022-08-05T10:00:52Z',
#    'content': 'Comment on this story\r\nSÃO PAULO Fatima Mendes tightens her grip on her dogs leashes as she crosses a street in the hemispheres largest city. The narrow sidewalks here are clotted with people draped … [+6974 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Rebecca Tan, Aung Naing Soe',
#    'title': "A love story, forged in Myanmar's political strife, ends in execution",
#    'description': 'The romance between activists Nilar Thein and Ko Jimmy endured coups, revolutions and prison sentences before being cut short last week.',
#    'url': 'https://www.washingtonpost.com/world/2022/08/05/myanmar-military-executions-ko-jimmy/',
# ...
#    'publishedAt': '2022-08-05T13:47:24Z',
#    'content': 'Comment on this story\r\nKABUL Rustam Haidery, 22, was watching a TikTok video in his bedroom Wednesday morning when a bullet smashed into the window ledge above his head. Leaping up, he saw uniformed … [+5878 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Amanda Coletta',
#    'title': 'Canada to ban the import of handguns, official says',
#    'description': "The ban, to take effect in two weeks, will allow Ottawa to stop imports without waiting for Parliament to pass legislation. But critics say it doesn't get at the real problem: Firearms smuggled illegally from the United States.",
#    'url': 'https://www.washingtonpost.com/world/2022/08/05/canada-handgun-import-ban/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/A6X2M7QHRUI63AFWIPZL7TDGMI.jpg&w=1440',
#    'publishedAt': '2022-08-05T12:36:32Z',
#    'content': 'Comment on this story\r\nTORONTO The Canadian government is planning to ban the import of handguns into the country, according to a government official, the latest in a series of gun-control measures t… [+5726 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Souad Mekhennet, Loveday Morris',
#    'title': "The brazen murder that spotlighted Berlin's timid Russia policy",
#    'description': "The unwillingness to punish President Vladimir Putin for a killing in Berlin ordered by Moscow added to the Kremlin's sense of impunity before the Ukraine war.",
#    'url': 'https://www.washingtonpost.com/world/2022/08/05/berlin-khangoshvili-krasikov-russia-killing/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/GTIYBRS5SQI6ZMPPZN4L44L7BY.jpg&w=1440',
#    'publishedAt': '2022-08-05T14:51:45Z',
#    'content': 'Comment on this story\r\nBERLIN Germanys new government had been in power for just a week last December when it was presented with a test of its mettle.\r\nIn a wood-paneled hearing room at Berlins highe… [+13917 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Steve Hendrix, Hazem Balousha',
#    'title': 'At least 7 dead after Israel strikes targets, kills militant leader in Gaza',
#    'description': "The attacks followed several days of threats from militants inside Gaza after Israel arrested an Islamic Jihad leader in the West Bank earlier in the week. Israel said it was targeting the group's leaders in the strikes.",
#    'url': 'https://www.washingtonpost.com/world/2022/08/05/israel-gaza-idf-strike/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/OYYDN3QUZQI63BECA3A4QTHI6I.jpg&w=1440',
#    'publishedAt': '2022-08-05T14:52:09Z',
#    'content': 'Comment on this story\r\nJERUSALEM The Israeli military launched air strikes on targets inside Gaza Friday, according to Israeli officials and people inside the enclave, killing a leader of an Islamic … [+2552 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Phil Davison',
#    'title': 'Roy Hackett, British civil rights pioneer, dies at 93',
#    'description': 'Inspired in part by the Montgomery bus boycott, he led a successful 1963 campaign for civil rights in Bristol, England.',
#    'url': 'https://www.washingtonpost.com/obituaries/2022/08/05/roy-hackett-civil-rights-dead/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/52C3PZQU3II63BECA3A4QTHI6I.jpg&w=1440',
#    'publishedAt': '2022-08-05T19:58:37Z',
#    'content': 'Inspired in part by the Montgomery bus boycott in Alabama, Jamaican-born British activist Roy Hackett partnered with a few friends to organize their own civil rights campaign in 1963, taking on the r… [+5003 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Simone Jacobson',
#    'title': 'Where to drink natural wine in the heart of Mexico',
#    'description': 'These wineries and bars around San Miguel de Allende pour natural wine made in Mexico.',
#    'url': 'https://www.washingtonpost.com/travel/2022/08/05/mexico-natural-wine-san-miguel/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/PYTGSFQPN4I63CHIYWG4HW5O4I.jpg&w=1440',
#    'publishedAt': '2022-08-05T13:08:51Z',
#    'content': 'Return to menuFounded nearly a decade ago, Cava Garambullo represents a partnership in wine and life between consultant and self-described professional taster Natalia López Mota and Branko Pjanic, a … [+1919 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Catherine Belton, Kareem Fahim',
#    'title': "Russia turns to Turkey, other trading partners to blunt sanctions' impact",
#    'description': 'Western government officials say Russia is seeking ways to circumvent war-related sanctions and their growing economic damage.',
#    'url': 'https://www.washingtonpost.com/world/2022/08/05/russia-turkey-war-sanctions-trade/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/TKITLMAIAEI63AFWIPZL7TDGMI.jpg&w=1440',
#    'publishedAt': '2022-08-05T07:00:59Z',
#    'content': 'Comment on this story\r\nRussia is turning to Turkey and other potential new trading partners as it tries to circumvent Western sanctions that are starting to bite even deeper into its economy followin… [+7776 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Michelle Ye Hee Lee, Christian Shepherd, Lily Kuo',
#    'title': 'Pelosi vows China will not isolate Taiwan amid military exercises',
#    'description': 'Meanwhile, the Taiwanese premier labeled China an "evil neighbor flexing its muscles on our doorstep" as tensions in the region soar.',
#    'url': 'https://www.washingtonpost.com/world/2022/08/04/pelosi-taiwan-visit-china-missile-japan/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/5RFWDJAUKUI63BECA3A4QTHI6I.jpg&w=1440',
#    'publishedAt': '2022-08-05T03:06:20Z',
#    'content': 'Comment on this story\r\nTOKYO House Speaker Nancy Pelosi vowed that China would not succeed in isolating Taiwan, as she capped off her Asia tour on Friday amid a flurry of Chinese military exercises t… [+3034 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Isabelle Khurshudyan, Erin Cunningham',
#    'title': 'The Nagorno-Karabakh conflict between Armenia and Azerbaijan, explained',
#    'description': 'Fresh clashes between Azerbaijan and Armenian-backed forces in Nagorno-Karabakh this week raised fears of a greater conflict.',
#    'url': 'https://www.washingtonpost.com/world/2022/08/04/nagorno-karabakh-conflict-explained/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/DKB6S3HPREI6XANSTNYGDJMC3A.jpg&w=1440',
#    'publishedAt': '2022-08-05T00:59:31Z',
#    'content': 'Comment on this story\r\nMOSCOW The conflict between Armenia and Azerbaijan over the contested Nagorno-Karabakh region has simmered for decades. In 2020, the two sides fought a bloody war for territory… [+767 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Sonia Rao',
#    'title': 'Kevin Spacey ordered to pay ‘House of Cards’ producers $30 million',
#    'description': 'Kevin Spacey ordered to pay ‘House of Cards’ producers $30 millionwashingtonpost.com',
#    'url': 'https://www.washingtonpost.com/arts-entertainment/2022/08/05/kevin-spacey-house-of-cards/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/UE2DSDQDLII63C7LFNHEQGYVAA.jpg&w=1440',
#    'publishedAt': '2022-08-05T17:16:31Z',
#    'content': 'Comment on this story\r\nA judge on Thursday ordered Kevin Spacey to pay more than $30 million to House of Cards producers for losses brought on by the actors firing in 2017 over sexual harassment alle… [+1698 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Ashley Spencer',
#    'title': 'Jennette McCurdy lived a teen star dream. Silently, she was suffering.',
#    'description': 'Former « iCarly » actress Jennette McCurdy discusses her abusive mother, eating disorders and Nickelodeon child star past in her memoir, « I’m Glad My Mom Died. »',
#    'url': 'https://www.washingtonpost.com/arts-entertainment/2022/08/05/jennette-mccurdy-memoir-interview/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/EXEC4LASXMI63BECA3A4QTHI6I.jpg&w=1440',
#    'publishedAt': '2022-08-05T10:00:20Z',
#    'content': 'Comment on this story\r\nPASADENA, Calif. For the entirety of her teens, Jennette McCurdy was a literal poster child for Nickelodeon stardom. Her face was beamed into millions of homes every week on ep… [+17961 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Steve Maas',
#    'title': 'A primer on Medicare prescription drug pricing - The Washington Post',
#    'description': 'A primer on Medicare prescription drug pricing\xa0\xa0The Washington Post',
#    'url': 'https://www.washingtonpost.com/outlook/2022/08/05/medicare-prescription-drug-manchin-schumer/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/YJEK4VSW6VEI3A7NJ5GHZ5R7JI.jpg&w=1440',
#    'publishedAt': '2022-08-05T19:08:18Z',
#    'content': 'Comment on this story\r\nWhat is the cost of a months supply of the blood pressure drug lisinopril, one of the most-prescribed medications for people on Medicare?\r\nA. $0\r\nB. $1\r\nC. $19\r\nD. $29\r\nE. All … [+13979 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Lauren Kaori Gurley',
#    'title': 'Employers added 528,000 jobs in July, as the hot labor market powers on',
#    'description': 'The labor market has been a pillar of strength for an economy dealing with surging inflation.',
#    'url': 'https://www.washingtonpost.com/business/2022/08/05/jobs-report-july-2022/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/QMKFY4GTFQI6VATLZQ4U3ASOGU.jpg&w=1440',
#    'publishedAt': '2022-08-05T12:36:18Z',
#    'content': 'Comment on this story\r\nThe hot labor market continued to show rapid growth in July, with employers adding 528,000jobs, despite fears of a recession.\r\nTheunemployment rateedged down to 3.5 percent, ac… [+5472 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'mtg',
#    'title': 'A Phoenix record store owner set the audiophile world on fire',
#    'description': 'Article URL: https://www.washingtonpost.com/music/2022/08/05/mofi-records-analog-digital-scandal/\nComments URL: https://news.ycombinator.com/item?id=32360340\nPoints: 4\n# Comments: 2',
#    'url': 'https://www.washingtonpost.com/music/2022/08/05/mofi-records-analog-digital-scandal/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/LAZLHZQNYAI63CHIYWG4HW5O4I.jpg&w=1440',
#    'publishedAt': '2022-08-05T18:54:12Z',
#    'content': 'Comment on this story\r\nMike Esposito still wont say who gave him the tip about the records. But on July 14, he went public with an explosive claim.\r\nIn a sometimes halting video posted to the YouTube… [+13417 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Fenit Nirappil',
#    'title': 'Children potentially exposed to monkeypox at Illinois daycare, officials say',
#    'description': 'A person who works at a daycare in Illinois has tested positive for monkeypox, potentially exposing children to the virus, state officials announced Friday.',
#    'url': 'https://www.washingtonpost.com/health/2022/08/05/monkeypox-illinois-daycare-center/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/HGCDAJAUAQI63BECA3A4QTHI6I.jpg&w=1440',
#    'publishedAt': '2022-08-05T21:47:17Z',
#    'content': 'Comment on this story\r\nA person who works at a day care in Illinois has tested positive for monkeypox, potentially exposing children to the virus, state officials announced Friday.\r\nOfficials are scr… [+3028 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Lindsey Bever',
#    'title': "Fauci warns people are 'going to get in trouble' with covid if not up to date on vaccines",
#    'description': 'Amid the latest omicron subvariant, Anthony S. Fauci, the nation’s top infectious-diseases expert, has a message: “If they don’t get vaccinated or they don’t get boosted, they’re going to get into trouble."',
#    'url': 'https://www.washingtonpost.com/health/2022/08/05/fauci-vaccine-covid-trouble/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/33MNP5AN5UI63CHIYWG4HW5O4I.jpg&w=1440',
#    'publishedAt': '2022-08-05T17:54:31Z',
#    'content': 'Comment on this story\r\nMore than two years into the coronavirus pandemic, Anthony S. Fauci, the nations top infectious diseases expert, said he understands people are exhausted, but is urging those w… [+3225 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Tony Romm',
#    'title': 'Democrats, Sinema reach deal on new taxes in health and climate bill',
#    'description': 'The new approach — along with other changes to the proposal known as the Inflation Reduction Act of 2022 — satisfied Sinema’s chief concerns and helped set in motion a plan to approve the bill as soon as this weekend.',
#    'url': 'https://www.washingtonpost.com/us-policy/2022/08/04/inflation-reduction-act-sinema/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/HUCTZJAR5MI63BECA3A4QTHI6I.jpg&w=1440',
#    'publishedAt': '2022-08-05T01:15:39Z',
#    'content': 'Comment on this story\r\nSen. Kyrsten Sinema (D-Ariz.) said she would soon be ready to move forward on a revised version of Senate Democrats health care, climate and deficit-reduction package, after pa… [+3119 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Fenit Nirappil',
#    'title': 'Monkeypox safe sex: CDC suggests fewer partners',
#    'description': 'The guidance was issued the day after the Biden administration declared the monkeypox outbreak a public health emergency.',
#    'url': 'https://www.washingtonpost.com/health/2022/08/05/monkeypox-sex-cdc-guidance/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/YN5NQDQSRYI63BECA3A4QTHI6I.jpg&w=1440',
#    'publishedAt': '2022-08-05T21:22:29Z',
#    'content': 'Comment on this story\r\nSexually active Americans should consider limiting partners and avoiding sex parties to reduce the risk of contracting monkeypox until they get vaccinated, according to updated… [+5428 chars]'}]}

# %%
len(r.json()['sources'])
# Out:
# 81

# %% [markdown]
# Drop table if exists

# %%
cass_session.execute(
    '''
    drop table if exists bakery.sources;
    '''
)

# %% [markdown]
# Create table if not exists

# %%
cass_session.execute(
    '''
    create table if not exists bakery.sources (
        id text,
        name text,
        description text,
        url text,
        category text,
        language text,
        country text,
        primary key (id)
    )
    '''
)

# %% [markdown]
# Write data to DB table

# %%
for s in tqdm(r.json()['sources'], total=len(r.json()['sources'])):
    values = (
        s['id'],
        s['name'],
        s['description'].replace("'", ""),
        s['url'],
        s['category'],
        s['language'],
        s['country']
    )
    cass_session.execute(
        f'''
        insert into bakery.sources (
            id, name, description, url, category, language, country
        ) values {values}
        '''
    )
# Out:
# 100%|█████████████████████████████████████████| 81/81 [00:00<00:00, 1638.73it/s]

# %% [markdown]
# ##### Get top headlines from yesterday

# %%
# Get list of sources from Cassandra table
# def list_factory(colnames, rows):
#     return [[row[0], row[1], row[2]] for row in rows]
# cass_session.row_factory = list_factory

# query = "select id, category, language from bakery.sources;"
# sources = cass_session.execute(query, timeout=None)
# sources = [source[0] for source in sources if source[1] in ['business', 'general'] and source[2] == 'en']

# %%
# sources

# %%
sources = [
    'time',
    'associated-press',
    'the-washington-post',
    'fox-news',
    'abc-news',
    'cnn',
    'nbc-news',
    'msnbc',
    'newsweek',
    'usa-today',
    'cbs-news',
    'reuters',
    'bbc-news',
    'the-wall-street-journal',
    'business-insider',
    'fortune',
    'bloomberg'
]

# %%
current_dttm = datetime.now()
from_dttm = (current_dttm - timedelta(days=1)).strftime('%Y-%m-%dT%H:%M:%S')
to_dttm = current_dttm.strftime('%Y-%m-%dT%H:%M:%S')
print(from_dttm, to_dttm)
# Out:
# 2022-08-07T11:56:12 2022-08-08T11:56:12

# %%
yesterday_dttm = str(date.today() - timedelta(days=1))
max_results = 500
endpoint = 'https://newsapi.org/v2/everything'
headers = {'Authorization' : creds['api_key']}
params = {
    'from': from_dttm,
    'to': to_dttm,
    'language': 'en',
    'sortBy': 'popularity'
}
articles = []

def chunker(ls, size):
    return (ls[pos:pos+size] for pos in range(0, len(ls), size))

for chunk in chunker(sources, 3):
    print(f'Sources: {", ".join(chunk)}')
    page = 1
    params['sources'] = ','.join(chunk)
    params['page'] = 1
    first_r = requests.get(endpoint, headers=headers, params=params)
    articles.extend(first_r.json()['articles'])
    total_results = first_r.json()['totalResults']
    print(f'\tTotal results: {total_results}')
    num_results = len(first_r.json()['articles'])
    if total_results > max_results:
        remaining_results = max_results - num_results
    else:
        remaining_results = total_results - num_results
    print('\tPage: {}, Status: {}, Remaining results: {}'.format(
                params['page'], 
                first_r.json()['status'],
                remaining_results
            )
         )
    while remaining_results > 0:
        params['page'] += 1
        r = requests.get(endpoint, headers=headers, params=params)
        articles.extend(r.json()['articles'])
        remaining_results -= len(r.json()['articles'])
        print('\tPage: {}, Status: {}, Remaining results: {}'.format(
                params['page'], 
                r.json()['status'],
                remaining_results
            )
         )
# Out:
# Sources: time, associated-press, the-washington-post
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [52], in <cell line: 16>()
#      20 params['page'] = 1
#      21 first_r = requests.get(endpoint, headers=headers, params=params)
# ---> 22 articles.extend(first_r.json()['articles'])
#      23 total_results = first_r.json()['totalResults']
#      24 print(f'\tTotal results: {total_results}')
#
# KeyError: 'articles'

# %%
first_r.json()
# Out:
# {'status': 'error',
#  'code': 'rateLimited',
#  'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}

# %%
articles_df = pd.DataFrame(articles)

# %%
articles_df[articles_df['title'].str.startswith('Hope fades as ')]
# Out:
#                                        source  \
# 549  {'id': 'usa-today', 'name': 'USA Today'}
#
#                                                 author  \
# 549  USA TODAY, George Petras and Janet Loehrke, US...
#
#                                                  title  \
# 549  Hope fades as starving Beluga whale stuck in F...
#
#                                            description  \
# 549  50 miles from Paris, Beluga continues to weake...
#
#                                                    url urlToImage  \
# 549  https://www.usatoday.com/restricted/?return=ht...       None
#
#               publishedAt                                            content
# 549  2022-08-07T19:37:35Z  Skip to main content\r\nThis content is only a...

# %%
articles_df[]
# Out:
#                                        source  \
# 0    {'id': 'bloomberg', 'name': 'Bloomberg'}
# 1    {'id': 'bloomberg', 'name': 'Bloomberg'}
# 2    {'id': 'bloomberg', 'name': 'Bloomberg'}
# 3    {'id': 'bloomberg', 'name': 'Bloomberg'}
# 4    {'id': 'bloomberg', 'name': 'Bloomberg'}
# ..                                        ...
# 98   {'id': 'bloomberg', 'name': 'Bloomberg'}
# 99   {'id': 'bloomberg', 'name': 'Bloomberg'}
# 100  {'id': 'bloomberg', 'name': 'Bloomberg'}
# 101  {'id': 'bloomberg', 'name': 'Bloomberg'}
# 102  {'id': 'bloomberg', 'name': 'Bloomberg'}
#
#                                            author  \
# 0                                    Amina Niasse
# 1                                Catarina Saraiva
# 2                                     Rich Miller
# 3    Erik Wasson, Steven T. Dennis, Laura Davison
# 4                               Albertina Torsoli
# ..                                            ...
# 98                                  Min Jeong Lee
# 99                                           None
# 100                                          None
# 101                                          None
# 102                Debjit Chakraborty, P R Sanjai
#
#                                                  title  \
# 0    'Bullet Train' Overcomes Mixed Reviews to Top ...
# 1    Daly Says Fed Is 'Far From Done Yet' on Bringi...
# 2    US Inflation Peak in Sight But Debate Rages Ov...
# 3    Senate Passes Democrats' Landmark Tax, Climate...
# 4    Renault Is On Right Track With New Electric Ve...
# ..                                                 ...
# 98   SoftBank Reports Record $23.4 Billion Loss as ...
# 99               Dennis Gartman on the Markets (Radio)
# 100            George Boubouras on the Markets (Radio)
# 101                Selina Sia on China Markets (Radio)
# 102  India's Billionaire Ambani Says Green Push to ...
#
#                                            description  \
# 0    “Bullet Train,” a Sony Corp. thriller starring...
# 1    San Francisco Fed President Mary Daly suggeste...
# 2    Sky-high US inflation may finally be approachi...
# 3    The Senate passed a landmark tax, climate and ...
# 4    Renault SA Chief Executive Officer Luca de Meo...
# ..                                                 ...
# 98   SoftBank Group Corp. reported a record 3.16 tr...
# 99   Live market coverage co-anchored from Hong Kon...
# 100  Live market coverage co-anchored from Hong Kon...
# 101  Live market coverage co-anchored from Hong Kon...
# 102  Reliance Industries Ltd., which pledged to spe...
#
#                                                    url  \
# 0    https://www.bloomberg.com/news/articles/2022-0...
# 1    https://www.bloomberg.com/news/articles/2022-0...
# 2    https://www.bloomberg.com/news/articles/2022-0...
# 3    https://www.bloomberg.com/news/articles/2022-0...
# 4    https://www.bloomberg.com/news/articles/2022-0...
# ..                                                 ...
# 98   https://www.bloomberg.com/news/articles/2022-0...
# 99   https://www.bloomberg.com/news/audio/2022-08-0...
# 100  https://www.bloomberg.com/news/audio/2022-08-0...
# 101  https://www.bloomberg.com/news/audio/2022-08-0...
# 102  https://www.bloomberg.com/news/articles/2022-0...
#
#                                             urlToImage           publishedAt  \
# 0    https://assets.bwbx.io/images/users/iqjWHBFdfx...  2022-08-07T15:49:49Z
# 1    https://assets.bwbx.io/images/users/iqjWHBFdfx...  2022-08-07T15:26:37Z
# 2    https://assets.bwbx.io/images/users/iqjWHBFdfx...  2022-08-07T13:00:01Z
# 3    https://assets.bwbx.io/images/users/iqjWHBFdfx...  2022-08-07T19:18:33Z
# 4    https://assets.bwbx.io/images/users/iqjWHBFdfx...  2022-08-07T11:06:54Z
# ..                                                 ...                   ...
# 98   https://assets.bwbx.io/images/users/iqjWHBFdfx...  2022-08-08T06:58:55Z
# 99   https://assets.bwbx.io/images/users/iqjWHBFdfx...  2022-08-07T22:39:40Z
# 100  https://assets.bwbx.io/images/users/iqjWHBFdfx...  2022-08-08T01:00:36Z
# 101  https://assets.bwbx.io/images/users/iqjWHBFdfx...  2022-08-08T01:40:54Z
# 102  https://assets.bwbx.io/images/users/iqjWHBFdfx...  2022-08-08T05:40:56Z
#
#                                                content
# 0    Bullet Train, a Sony Corp. thriller starring B...
# 1    San Francisco Fed President Mary Daly suggeste...
# 2    Sky-high US inflation may finally be approachi...
# 3    The Senate passed a landmark tax, climate and ...
# 4    Renault SA Chief Executive Officer Luca de Meo...
# ..                                                 ...
# 98   SoftBank Group Corp. reported a record 3.16 tr...
# 99   Live market coverage co-anchored from Hong Kon...
# 100  Live market coverage co-anchored from Hong Kon...
# 101  Live market coverage co-anchored from Hong Kon...
# 102  Reliance Industries Ltd., which pledged to spe...
#
# [103 rows x 8 columns]

# %%
r.json()['articles'][0]['description'].replace("'", '"')
# Out:
# 'Live market coverage co-anchored from Hong Kong and New York. Overnight on Wall Street is daytime in Asia. Markets never sleep, and neither does Bloomberg.'

# %%
str(r.json()['articles'][0]['author'])
# Out:
# 'None'
